# %%
# Importing Libraries
import selenium
import pandas as pd
import time

# Importing selenium webdriver 
from selenium import webdriver

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
#Pasting the installed msedge path
driver=webdriver.Edge(r'C:\Users\satvi\OneDrive\Desktop\msedgedriver.exe')

# %% [markdown]
# ### Scraping the details using selenium

# %% [markdown]
# ### OLX used cars list

# %%
#getting the url
url = "https://www.olx.in/cars_c84"
driver.get(url)
time.sleep(2)

# %%
start=0
end=5
for page in range(start,end):
    car_urls = []
    url=driver.find_elements_by_xpath('//li[@class="EIR5N"]/a')       
    for i in url:
        car_urls.append(i.get_attribute("href"))                       
car_urls
# Out:
# ['https://www.olx.in/item/maruti-suzuki-s-cross-zeta-13-2016-diesel-iid-1631370857',
#  'https://www.olx.in/item/maruti-suzuki-alto-lx-2007-petrol-iid-1656100231',
#  'https://www.olx.in/item/maruti-suzuki-swift-dzire-zdi-2010-diesel-iid-1651798861',
#  'https://www.olx.in/item/honda-wr-v-i-dtec-vx-2017-diesel-iid-1645100761',
#  'https://www.olx.in/item/ford-ecosport-15-petrol-titanium-plus-at-2017-petrol-iid-1644271163',
#  'https://www.olx.in/item/mercedes-benz-gle-class-others-2020-diesel-iid-1651457349',
#  'https://www.olx.in/item/maruti-suzuki-ciaz-13-delta-2020-petrol-iid-1656686561',
#  'https://www.olx.in/item/fiat-linea-classic-2016-petrol-37000-km-driven-iid-1656686550',
#  'https://www.olx.in/item/maruti-suzuki-eeco-7-seater-standard-2010-petrol-iid-1633339864',
#  'https://www.olx.in/item/hyundai-grand-i10-sportz-12-kappa-vtvt-2016-petrol-iid-1655033948',
#  'https://www.olx.in/item/maruti-suzuki-celerio-zxi-optional-amt-2019-petrol-iid-1649749657',
# ...

# %%
Price=[]
try:
    price=driver.find_elements_by_xpath('//span[@class="_89yzn"]')
    for i in price:
        Price.append(i.text)
except NoSuchElementException:
    Price.append('-')
Price
# Out:
# ['₹ 6,70,000',
#  '₹ 1,55,000',
#  '₹ 3,40,000',
#  '₹ 7,50,000',
#  '₹ 7,90,000',
#  '₹ 88,10,000',
#  '₹ 8,45,000',
#  '₹ 3,00,000',
#  '₹ 1,99,991',
#  '₹ 4,81,000',
#  '₹ 4,50,000',
#  '₹ 11,95,000',
#  '₹ 3,50,000',
#  '₹ 38,00,000',
#  '₹ 3,80,000',
#  '₹ 3,35,000',
#  '₹ 1,65,000',
#  '₹ 60,000',
#  '₹ 1,75,000',
#  '₹ 35,000',
#  '₹ 90,000',
#  '₹ 60,000',
#  '₹ 15,000',
#  '₹ 3,25,000',
#  '₹ 20,00,000',
#  '₹ 23,51,000',
#  '₹ 4,11,000',
#  '₹ 5,75,000',
#  '₹ 6,00,000',
#  '₹ 2,75,000',
#  '₹ 7,50,000',
#  '₹ 2,70,000',
#  '₹ 4,75,000',
#  '₹ 2,65,000',
#  '₹ 1,45,000',
#  '₹ 25,000',
#  '₹ 16,00,000',
#  '₹ 1,00,000',
#  '₹ 2,05,000',
#  '₹ 14,80,000']

# %%
brand=[]
try:
    Brand=driver.find_elements_by_xpath('//span[@class="_2tW1I"]')
    for i in Brand:
        brand.append(i.text.split(','))
except NoSuchElementException:
    brand.append('-')
brand
# Out:
# [['Maruti Suzuki S-Cross Zeta 1.3', ' 2016', ' Diesel'],
#  ['Maruti Suzuki Alto LX', ' 2007', ' Petrol'],
#  ['Maruti Suzuki Swift Dzire ZDI', ' 2010', ' Diesel'],
#  ['Honda WR-V i-DTEC VX', ' 2017', ' Diesel'],
#  ['Ford Ecosport 1.5 Petrol Titanium Plus AT', ' 2017', ' Petrol'],
#  ['Mercedes-Benz GLE Class Others', ' 2020', ' Diesel'],
#  ['Maruti Suzuki Ciaz 1.3 Delta', ' 2020', ' Petrol'],
#  ['Fiat Linea Classic 2016 Petrol 37000 Km Driven'],
#  ['Maruti Suzuki Eeco 7 Seater Standard', ' 2010', ' Petrol'],
#  ['Hyundai Grand i10 Sportz 1.2 Kappa VTVT', ' 2016', ' Petrol'],
#  ['Maruti Suzuki Celerio ZXI Optional AMT', ' 2019', ' Petrol'],
#  ['Skoda Octavia 2013-2017 Elegance 2.0 TDI AT', ' 2016', ' Diesel'],
#  ['Hyundai Grand i10 2016 Diesel Well Maintained'],
#  ['Jaguar F-Pace Prestige 2.0 AWD', ' 2018', ' Diesel'],
#  ['Maruti Suzuki Wagon R LXI', ' 2017'],
#  ['Hyundai i20 Diesel Asta', ' 2011', ' Diesel'],
#  ['Chevrolet Spark LT 1.0 LPG', ' 2011', ' Petrol'],
# ...

# %%
place=[]
try:
    Place=driver.find_elements_by_xpath('//span[@class="tjgMj"]')
    for i in Place:
        place.append(i.text.split(','))
except NoSuchElementException:
    place.append('-')
place
# Out:
# [['SECTOR 16', ' PANCHKULA'],
#  ['NANDINI LAYOUT', ' BENGALURU'],
#  ['PRAGATI NAGAR', ' AHMEDABAD'],
#  ['LAJPAT NAGAR 1', ' DELHI'],
#  ['ASHOK VIHAR', ' DELHI'],
#  ['BORIVALI WEST', ' MUMBAI'],
#  ['HANSAPAL', ' BHUBANESHWAR'],
#  ['BHIULI', ' MANDI'],
#  ['SALTLAKE SECTOR 1', ' KOLKATA'],
#  ['NUNGAMBAKKAM', ' CHENNAI'],
#  ['GEETA COLONY', ' DELHI'],
#  ['ASHOK VIHAR', ' DELHI'],
#  ['AALI', ' DELHI'],
#  ['CHANDIGARH AIRPORT AREA', ' CHANDIGARH'],
#  ['BEYPORE', ' KOZHIKODE'],
#  ['KAMAKSHIPALYA', ' BENGALURU'],
#  ['KOLATHUR', ' CHENNAI'],
#  ['VIJAY NAGAR', ' KOTKAPURA'],
#  ['SATELLITE CITY', ' RAJAHMUNDRY'],
#  ['BHAMIAN KALAN', ' LUDHIANA'],
#  ['KAKKANCHERY', ' KOZHIKODE'],
#  ['PEREN', ' NAGALAND'],
#  ['BEHLANA', ' CHANDIGARH'],
#  ['TUKARAM NAGAR', ' TALEGAON DABHADE'],
#  ['ERNAKULAM', ' KOCHI'],
#  ['SATELLITE', ' AHMEDABAD'],
#  ['NARODA', ' AHMEDABAD'],
#  ['ARADHANA NAGAR', ' BHOPAL'],
#  ['MANIKTALA', ' KOLKATA'],
#  ['CHANDRA LAYOUT', ' BENGALURU'],
# ...

# %%
kilometers=[]
for i in car_urls:
    driver.get(i)
    time.sleep(2)
    try:
        kms=driver.find_elements_by_xpath('//*[@id="container"]/main/div/div/div/div[5]/div[1]/div[1]/div[1]/div/div[4]/div[2]/div')
        for i in kms:
            kilometers.append(i.text)
    except NoSuchElementException:
        kilometers.append('-')
kilometers
# Out:
# ['78000.0 KM',
#  '78000.0 KM',
#  '65000.0 KM',
#  '44000 KM',
#  '44000 KM',
#  '11800.0 KM',
#  '22000.0 KM',
#  '37,000 KM',
#  '62608.0 KM',
#  '24924.0 KM',
#  '9000.0 KM',
#  '53000 KM',
#  '61204 KM',
#  '21000.0 KM',
#  '47000.0 KM',
#  '76000.0 KM',
#  '78800.0 KM',
#  '150,000 KM',
#  '24,000 KM',
#  '45,000 KM',
#  '0 KM',
#  '50,000 KM',
#  '0 KM',
#  '91,900 KM',
#  '72000.0 KM',
#  '128000.0 KM',
#  '69000.0 KM',
#  '56553 KM',
#  '50509 KM',
#  '88000.0 KM',
#  '39859.0 KM',
#  '20 KM',
#  '50000.0 KM',
#  '45000.0 KM',
#  '50,000 KM',
#  '2,000 KM',
#  '91,000 KM',
#  '80,000 KM',
#  '83,000 KM',
#  '1,263 KM']

# %%
owners=[]
for i in car_urls:
    driver.get(i)
    time.sleep(2)
    try:
        no=driver.find_elements_by_xpath('//*[@id="container"]/main/div/div/div/div[5]/div[1]/div[2]/div/div[2]/div/div[1]/div[2]/div[2]')
        for i in no:
            owners.append(i.text)
    except NoSuchElementException:
        owners.append('-')
owners
# Out:
# ['2nd',
#  '2nd',
#  '1st',
#  'First',
#  'First',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '--',
#  '2nd',
#  'First',
#  'First',
#  '2nd',
#  '2nd',
#  '2nd',
#  '1st',
#  '3rd',
#  '2nd',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  'Second',
#  'First',
#  '2nd',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st']

# %%
# creating a pandas dataframe
df = pd.DataFrame(brand, 
                  columns = ['model', 'model-year', 
                             'fuel-type'])
  
# show the dataframe
df
# Out:
#                                                 model model-year fuel-type
# 0                      Maruti Suzuki S-Cross Zeta 1.3       2016    Diesel
# 1                               Maruti Suzuki Alto LX       2007    Petrol
# 2                       Maruti Suzuki Swift Dzire ZDI       2010    Diesel
# 3                                Honda WR-V i-DTEC VX       2017    Diesel
# 4           Ford Ecosport 1.5 Petrol Titanium Plus AT       2017    Petrol
# 5                      Mercedes-Benz GLE Class Others       2020    Diesel
# 6                        Maruti Suzuki Ciaz 1.3 Delta       2020    Petrol
# 7      Fiat Linea Classic 2016 Petrol 37000 Km Driven       None      None
# 8                Maruti Suzuki Eeco 7 Seater Standard       2010    Petrol
# 9             Hyundai Grand i10 Sportz 1.2 Kappa VTVT       2016    Petrol
# 10             Maruti Suzuki Celerio ZXI Optional AMT       2019    Petrol
# ...

# %%
# creating a pandas dataframe
df1 = pd.DataFrame(place, 
                  columns = ['area', 'location'])
  
# show the dataframe
df1
# Out:
#                           area                   location
# 0                    SECTOR 16                  PANCHKULA
# 1               NANDINI LAYOUT                  BENGALURU
# 2                PRAGATI NAGAR                  AHMEDABAD
# 3               LAJPAT NAGAR 1                      DELHI
# 4                  ASHOK VIHAR                      DELHI
# 5                BORIVALI WEST                     MUMBAI
# 6                     HANSAPAL               BHUBANESHWAR
# 7                       BHIULI                      MANDI
# 8            SALTLAKE SECTOR 1                    KOLKATA
# 9                 NUNGAMBAKKAM                    CHENNAI
# 10                GEETA COLONY                      DELHI
# 11                 ASHOK VIHAR                      DELHI
# 12                        AALI                      DELHI
# 13     CHANDIGARH AIRPORT AREA                 CHANDIGARH
# 14                     BEYPORE                  KOZHIKODE
# ...

# %%
df1.drop(columns=['area'],axis=1,inplace=True)

# %%
len(kilometers),len(owners),len(Price)
# Out:
# (40, 40, 40)

# %%
olx=pd.DataFrame({'website':'olx','driven kilometers':kilometers,'No of owners':owners,'Price':Price})
olx
# Out:
#    website driven kilometers No of owners        Price
# 0      olx        78000.0 KM          2nd   ₹ 6,70,000
# 1      olx        78000.0 KM          2nd   ₹ 1,55,000
# 2      olx        65000.0 KM          1st   ₹ 3,40,000
# 3      olx          44000 KM        First   ₹ 7,50,000
# 4      olx          44000 KM        First   ₹ 7,90,000
# 5      olx        11800.0 KM          1st  ₹ 88,10,000
# 6      olx        22000.0 KM          1st   ₹ 8,45,000
# 7      olx         37,000 KM          2nd   ₹ 3,00,000
# 8      olx        62608.0 KM          1st   ₹ 1,99,991
# 9      olx        24924.0 KM           --   ₹ 4,81,000
# 10     olx         9000.0 KM          2nd   ₹ 4,50,000
# 11     olx          53000 KM        First  ₹ 11,95,000
# 12     olx          61204 KM        First   ₹ 3,50,000
# 13     olx        21000.0 KM          2nd  ₹ 38,00,000
# 14     olx        47000.0 KM          2nd   ₹ 3,80,000
# 15     olx        76000.0 KM          2nd   ₹ 3,35,000
# ...

# %%
data=pd.concat([df,df1,olx],axis=1)
data
# Out:
#                                                 model model-year fuel-type  \
# 0                      Maruti Suzuki S-Cross Zeta 1.3       2016    Diesel
# 1                               Maruti Suzuki Alto LX       2007    Petrol
# 2                       Maruti Suzuki Swift Dzire ZDI       2010    Diesel
# 3                                Honda WR-V i-DTEC VX       2017    Diesel
# 4           Ford Ecosport 1.5 Petrol Titanium Plus AT       2017    Petrol
# 5                      Mercedes-Benz GLE Class Others       2020    Diesel
# 6                        Maruti Suzuki Ciaz 1.3 Delta       2020    Petrol
# 7      Fiat Linea Classic 2016 Petrol 37000 Km Driven       None      None
# 8                Maruti Suzuki Eeco 7 Seater Standard       2010    Petrol
# 9             Hyundai Grand i10 Sportz 1.2 Kappa VTVT       2016    Petrol
# 10             Maruti Suzuki Celerio ZXI Optional AMT       2019    Petrol
# ...

# %% [markdown]
# ### CarDekho used cars list

# %%
#getting the url
url = "https://www.cardekho.com/buy-used-cars+in+bangalore"
driver.get(url)
time.sleep(2)

# %%
car_urls = []
url=driver.find_elements_by_xpath('//div[@class="gsc_col-xs-6 carsName"]/a')       
for i in url:
    car_urls.append(i.get_attribute("href"))                       
car_urls
# Out:
# ['https://www.cardekho.com/buy-used-car-details/used-Maruti-Alto-800-Lxi-cars-Bangalore_136d77d5-5a65-4d49-be7d-943deb3f9c56.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Maruti-Celerio-Vxi-Amt-Bsiv-cars-Bangalore_c156f162-0d94-44ab-b9a1-62b99c61e245.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Maruti-Celerio-Vxi-At-cars-Bangalore_d59a9fca-0334-4b30-acb9-102bbf9bf4d6.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Hyundai-I10-Magna-1.1l-cars-Bangalore_bb11337a-885d-4716-bbb6-ef7583a4b03e.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Maruti-Celerio-Zxi-At-cars-Bangalore_4ac8f1b5-3bb6-4fef-a43f-a24dd25efc8f.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Maruti-Celerio-Vxi-Optional-cars-Bangalore_5012d4fc-a165-465d-8a0c-9c0a9149791e.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Mahindra-Tuv-300-T8-cars-Bangalore_da983f56-347f-4679-98eb-dc1d8ec2a3d8.htm',
# ...

# %%
model=[]
try:
    brand=driver.find_elements_by_xpath('//div[@class="gsc_col-xs-6 carsName"]/a')
    for i in brand:
        model.append(i.text)
except NoSuchElementException:
    model.append('-')
model
# Out:
# ['2015 Maruti Alto 800',
#  '2016 Maruti Celerio',
#  '2014 Maruti Celerio',
#  '2012 Hyundai I10',
#  '2016 Maruti Celerio',
#  '2016 Maruti Celerio',
#  '2017 Mahindra Tuv 300',
#  '2018 Maruti Celerio',
#  '2015 Maruti Celerio',
#  '2019 Maruti Eeco',
#  '2011 Maruti Swift',
#  '2018 Maruti Eeco',
#  '2019 Hyundai Grand I10',
#  '2018 Maruti Ignis',
#  '2016 Maruti Celerio',
#  '2013 Hyundai Eon',
#  '2019 Maruti Alto 800',
#  '2017 Tata Tiago',
#  '2017 Maruti Wagon R',
#  '2017 Maruti Wagon R',
#  '2010 Maruti Swift Dzire',
#  '2018 Renault Kwid',
#  '2014 Maruti Alto 800',
#  '2019 Hyundai Grand I10',
#  '2014 Maruti Swift Dzire',
#  '2012 Maruti Alto K10',
#  '2013 Maruti Swift Dzire',
#  '2020 Tata Tiago',
#  '2015 Maruti Celerio',
#  '2017 Renault Kwid',
#  '2011 Hyundai I10',
#  '2014 Maruti Swift',
#  '2014 Maruti Swift Dzire',
#  '2014 Honda Brio',
#  '2013 Maruti Swift',
#  '2008 Hyundai I10',
#  '2017 Maruti Celerio',
#  '2013 Hyundai Eon',
#  '2018 Hyundai Eon',
# ...

# %%
Price=[]
try:
    price=driver.find_elements_by_xpath('//span[@class="amnt "]')
    for i in price:
        Price.append(i.text)
except NoSuchElementException:
    Price.append('-')
Price
# Out:
# ['2,90,500',
#  '4,53,500',
#  '4,31,000',
#  '3,49,500',
#  '4,33,000',
#  '4,32,500',
#  '7,27,000',
#  '4,97,500',
#  '4,60,500',
#  '4,55,500',
#  '4,19,500',
#  '4,45,500',
#  '6,48,500',
#  '6,22,000',
#  '4,61,500',
#  '2,79,500',
#  '3,72,500',
#  '4,78,500',
#  '4,77,000',
#  '4,75,500',
#  '3,62,500',
#  '4,01,000',
#  '2,62,000',
#  '6,10,500',
#  '5,40,000',
#  '2,87,500',
#  '5,02,500',
#  '6,63,500',
#  '4,39,500',
#  '4,14,500',
#  '3,08,500',
#  '4,84,500',
#  '5,09,500',
#  '3,94,500',
#  '4,78,000',
#  '2,95,500',
#  '4,76,500',
#  '2,86,000',
#  '3,80,000',
#  '7,44,000',
#  '6,14,000',
#  '4,18,500',
#  '2,84,000',
#  '2,65,000',
#  '5,58,500',
#  '3,44,500',
#  '3,34,000',
#  '2,82,000',
#  '6,19,000',
#  '4,40,700',
#  '6,26,500',
#  '5,09,500',
#  '3,30,000',
#  '3,85,500',
#  '5,67,500',
#  '3,68,500',
#  '7,91,000',
#  '5,83,000',
#  '4,45,000',
#  '5,65,000',
#  '3,17,500',
#  '2,49,000',
#  '4,27,000',
#  '7,10,000',
#  '4,83,000',
#  '5,01,000',
# ...

# %%
kilometers=[]
for i in car_urls:
    driver.get(i)
    time.sleep(2)
    try:
        kms=driver.find_elements_by_xpath('//*[@id="rf01"]/div[1]/div/div/main/div/div/div[1]/div[3]/div/div/div/ul/li[4]/div/div[2]')
        for i in kms:
            kilometers.append(i.text)
    except NoSuchElementException:
        kilometers.append('-')
kilometers
# Out:
# ['42,358 Kms',
#  '26,884 Kms',
#  '41,775 Kms',
#  '30,858 Kms',
#  '41,651 Kms',
#  '19,668 Kms',
#  '45,484 Kms',
#  '20,675 Kms',
#  '17,042 Kms',
#  '30,661 Kms',
#  '24,855 Kms',
#  '22,004 Kms',
#  '15,726 Kms',
#  '13,107 Kms',
#  '46,103 Kms',
#  '34,502 Kms',
#  '2,083 Kms',
#  '73,108 Kms',
#  '45,448 Kms',
#  '24,925 Kms',
#  '66,749 Kms',
#  '46,527 Kms',
#  '34,929 Kms',
#  '3,332 Kms',
#  '74,444 Kms',
#  '59,050 Kms',
#  '35,949 Kms',
#  '28,656 Kms',
#  '25,610 Kms',
#  '12,413 Kms',
#  '63,300 Kms',
#  '57,544 Kms',
#  '86,857 Kms',
#  '54,977 Kms',
#  '107,408 Kms',
#  '62,500 Kms',
#  '21,042 Kms',
#  '34,000 Kms',
#  '15,998 Kms',
#  '28,782 Kms',
#  '13,136 Kms',
#  '25,772 Kms',
#  '51,503 Kms',
#  '79,209 Kms',
#  '115,848 Kms',
#  '42,631 Kms',
#  '32,984 Kms',
#  '65,713 Kms',
#  '23,720 Kms',
#  '104,201 Kms',
#  '30,870 Kms',
#  '44,870 Kms',
#  '118,480 Kms',
#  '55,656 Kms',
#  '40,679 Kms',
#  '34,981 Kms',
#  '45,645 Kms',
#  '56,410 Kms',
# ...

# %%
owners=[]
for i in car_urls:
    driver.get(i)
    time.sleep(2)
    try:
        no=driver.find_elements_by_xpath('//*[@id="rf01"]/div[1]/div/div/main/div/div/div[1]/div[3]/div/div/div/ul/li[6]/div/div[2]')
        for i in no:
            owners.append(i.text)
    except NoSuchElementException:
        owners.append('-')
owners
# Out:
# ['2nd Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '3rd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
# ...

# %%
model_year=[]
for i in car_urls:
    driver.get(i)
    time.sleep(2)
    try:
        Brand=driver.find_elements_by_xpath('//*[@id="rf01"]/div[1]/div/div/main/div/div/div[1]/div[3]/div/div/div/ul/li[1]/div/div[2]')
        for i in Brand:
            model_year.append(i.text)
    except NoSuchElementException:
        model_year.append('-')
model_year
# Out:
# ['2015',
#  '2016',
#  '2014',
#  '2012',
#  '2015',
#  '2016',
#  '2016',
#  '2018',
#  '2015',
#  '2019',
#  '2011',
#  '2018',
#  '2019',
#  '2017',
#  '2015',
#  '2013',
#  '2019',
#  '2016',
#  '2017',
#  '2017',
#  '2010',
#  '2018',
#  '2014',
#  '2019',
#  '2013',
#  '2012',
#  '2013',
#  '2019',
#  '2015',
#  '2017',
#  '2011',
#  '2013',
#  '2014',
#  '2013',
#  '2013',
#  '2008',
#  '2017',
#  '2013',
#  '2017',
#  '2018',
#  '2017',
#  '2018',
#  '2010',
#  '2009',
#  '2014',
#  '2011',
#  '2016',
#  '2010',
#  '2016',
#  '2013',
#  '2016',
#  '2014',
#  '2010',
#  '2013',
#  '2014',
#  '2012',
#  '2017',
#  '2015',
#  '2013',
#  '2015',
#  '2011',
#  '2013',
#  '2013',
#  '2015',
#  '2013',
#  '2012',
#  '2019',
#  '2015',
#  '2009',
#  '2018',
#  '2011',
#  '2017',
#  '2015',
#  '2018',
#  '2018',
#  '2018',
#  '2012',
#  '2019',
#  '2015',
#  '2014',
#  '2017',
#  '2017',
#  '2015',
#  '2015',
#  '2016',
#  '2018',
#  '2017',
#  '2018',
#  '2016',
#  '2016',
# ...

# %%
fuel_type=[]
for i in car_urls:
    driver.get(i)
    time.sleep(2)
    try:
        type=driver.find_elements_by_xpath('//*[@id="rf01"]/div[1]/div/div/main/div/div/div[1]/div[3]/div/div/div/ul/li[3]/div/div[2]')
        for i in type:
            fuel_type.append(i.text)
    except NoSuchElementException:
        fuel_type.append('-')
fuel_type
# Out:
# ['Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
# ...

# %%
# creating a pandas dataframe
data1 = pd.DataFrame({'website':'Cardekho','model':model,'model_year':model_year,'fuel-type':fuel_type,'location':'Bangalore','driven kilometers':kilometers,'No of owners':owners,'Price':Price})
  # show the dataframe
data1
# Out:
#       website                  model model_year fuel-type   location  \
# 0    Cardekho   2015 Maruti Alto 800       2015    Petrol  Bangalore
# 1    Cardekho    2016 Maruti Celerio       2016    Petrol  Bangalore
# 2    Cardekho    2014 Maruti Celerio       2014    Petrol  Bangalore
# 3    Cardekho       2012 Hyundai I10       2012    Petrol  Bangalore
# 4    Cardekho    2016 Maruti Celerio       2015    Petrol  Bangalore
# ..        ...                    ...        ...       ...        ...
# 175  Cardekho       2010 Hyundai I20       2010    Petrol  Bangalore
# 176  Cardekho    2014 Renault Duster       2013    Diesel  Bangalore
# 177  Cardekho       2011 Hyundai I20       2011    Petrol  Bangalore
# 178  Cardekho       2015 Hyundai Eon       2015    Petrol  Bangalore
# 179  Cardekho  2016 Mahindra Tuv 300       2016    Diesel  Bangalore
#
#     driven kilometers No of owners     Price
# 0          42,358 Kms    2nd Owner  2,90,500
# 1          26,884 Kms    2nd Owner  4,53,500
# ...

# %%
#getting the url
url = "https://www.cardekho.com/buy-used-cars+in+delhi-ncr"
driver.get(url)
time.sleep(2)

# %%
car_urls = []
url=driver.find_elements_by_xpath('//div[@class="gsc_col-xs-6 carsName"]/a')       
for i in url:
    car_urls.append(i.get_attribute("href"))                       
car_urls
# Out:
# ['https://www.cardekho.com/buy-used-car-details/used-Maruti-Alto-K10-Vxi-cars-Ghaziabad_fb0f14f5-f97b-483a-bf6a-955018b787e1.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Tata-Tiago-1.2-Revotron-Xz-cars-Ghaziabad_65142096-da9b-4de3-8f43-e6165d2dfbab.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Maruti-Alto-K10-2010-2014-Vxi-cars-Ghaziabad_7f302c14-b7ef-4adf-9823-1833ddba1fe0.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Hyundai-Grand-I10-1.2-Kappa-Sportz-Bsiv-cars-Ghaziabad_84392163-26b3-4abb-9297-052d3be0234f.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Hyundai-Grand-I10-1.2-Crdi-Magna-cars-Ghaziabad_812f99c1-fc53-4eb4-ba19-ba6b37169742.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Maruti-Baleno-Delta-cars-Ghaziabad_6b597b4a-f615-489d-b257-2484cba7c0d9.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Maruti-Wagon-R-Vxi-1.2-cars-Ghaziabad_a7fd7165-836e-42c0-9df4-c4c21c0237f6.htm',
# ...

# %%
model=[]
try:
    brand=driver.find_elements_by_xpath('//div[@class="gsc_col-xs-6 carsName"]/a')
    for i in brand:
        model.append(i.text)
except NoSuchElementException:
    model.append('-')
model
# Out:
# ['2018 Maruti Alto K10',
#  '2020 Tata Tiago',
#  '2013 Maruti Alto K10',
#  '2019 Hyundai Grand I10',
#  '2017 Hyundai Grand I10',
#  '2018 Maruti Baleno',
#  '2019 Maruti Wagon R',
#  '2018 Maruti Alto K10',
#  '2015 Maruti Ciaz',
#  '2018 Maruti Swift Dzire',
#  '2016 Hyundai Grand I10',
#  '2017 Maruti Ciaz',
#  '2017 Maruti Swift',
#  '2019 Maruti Baleno',
#  '2018 Maruti Swift',
#  '2015 Maruti Swift Dzire',
#  '2017 Hyundai I20',
#  '2019 Hyundai Venue',
#  '2015 Honda City',
#  '2020 Maruti Baleno',
#  '2016 Maruti Swift',
#  '2018 Tata Tigor',
#  '2012 Maruti Alto K10',
#  '2019 Volkswagen Polo',
#  '2015 Maruti Swift Dzire',
#  '2015 Maruti Ciaz',
#  '2019 Maruti Wagon R',
#  '2019 Volkswagen Ameo',
#  '2018 Maruti Swift',
#  '2018 Maruti Alto K10',
#  '2012 Maruti Alto K10',
#  '2019 Toyota Yaris',
#  '2017 Hyundai I20',
#  '2017 Maruti Ciaz',
#  '2020 Renault Kwid',
#  '2019 Maruti Swift Dzire',
#  '2017 Maruti Alto 800',
#  '2019 Tata Tiago',
#  '2017 Maruti Wagon R',
# ...

# %%
Price=[]
try:
    price=driver.find_elements_by_xpath('//span[@class="amnt "]')
    for i in price:
        Price.append(i.text)
except NoSuchElementException:
    Price.append('-')
Price
# Out:
# ['3,61,000',
#  '5,40,500',
#  '2,54,500',
#  '5,50,500',
#  '4,10,215',
#  '5,66,000',
#  '5,13,000',
#  '3,56,000',
#  '5,07,000',
#  '5,79,000',
#  '4,34,500',
#  '7,00,500',
#  '4,39,272',
#  '6,95,500',
#  '6,39,330',
#  '4,56,500',
#  '5,69,000',
#  '9,90,552',
#  '6,76,500',
#  '5,76,000',
#  '4,11,020',
#  '5,13,916',
#  '1,92,000',
#  '5,37,500',
#  '4,20,500',
#  '4,70,000',
#  '4,76,000',
#  '4,82,612',
#  '5,72,794',
#  '3,45,000',
#  '2,24,000',
#  '10,17,390',
#  '5,62,140',
#  '6,60,948',
#  '3,62,187',
#  '6,54,000',
#  '2,48,600',
#  '4,51,000',
#  '3,22,000',
#  '4,90,000',
#  '4,11,020',
#  '5,13,916',
#  '1,92,000',
#  '5,37,500',
#  '4,20,500',
#  '4,70,000',
#  '4,76,000',
#  '4,82,612',
#  '5,72,794',
#  '3,45,000',
#  '2,24,000',
#  '10,17,390',
#  '5,62,140',
#  '6,60,948',
#  '3,62,187',
#  '6,54,000',
#  '2,48,600',
#  '4,51,000',
#  '3,22,000',
#  '4,90,000',
#  '5,70,912',
#  '6,65,871',
#  '5,41,681',
#  '4,71,000',
#  '4,53,948',
#  '4,69,500',
# ...

# %%
kilometers=[]
for i in car_urls:
    driver.get(i)
    time.sleep(2)
    try:
        kms=driver.find_elements_by_xpath('//*[@id="rf01"]/div[1]/div/div/main/div/div/div[1]/div[3]/div/div/div/ul/li[4]/div/div[2]')
        for i in kms:
            kilometers.append(i.text)
    except NoSuchElementException:
        kilometers.append('-')
kilometers
# Out:
# ['18,819 Kms',
#  '6,947 Kms',
#  '63,762 Kms',
#  '12,598 Kms',
#  '61,639 Kms',
#  '15,295 Kms',
#  '21,598 Kms',
#  '32,915 Kms',
#  '77,891 Kms',
#  '38,694 Kms',
#  '39,842 Kms',
#  '68,634 Kms',
#  '27,735 Kms',
#  '5,932 Kms',
#  '69,233 Kms',
#  '88,285 Kms',
#  '23,091 Kms',
#  '58,169 Kms',
#  '96,400 Kms',
#  '13,803 Kms',
#  '53,525 Kms',
#  '34,688 Kms',
#  '58,877 Kms',
#  '8,559 Kms',
#  '79,842 Kms',
#  '78,667 Kms',
#  '6,732 Kms',
#  '16,802 Kms',
#  '14,096 Kms',
#  '44,973 Kms',
#  '42,641 Kms',
#  '5,021 Kms',
#  '40,486 Kms',
#  '21,231 Kms',
#  '15,900 Kms',
#  '6,937 Kms',
#  '38,200 Kms',
#  '20,463 Kms',
#  '46,742 Kms',
#  '67,565 Kms',
#  '53,525 Kms',
#  '34,688 Kms',
#  '58,877 Kms',
#  '8,559 Kms',
#  '79,842 Kms',
#  '78,667 Kms',
#  '6,732 Kms',
#  '16,802 Kms',
#  '14,096 Kms',
#  '44,973 Kms',
#  '42,641 Kms',
#  '5,021 Kms',
#  '40,486 Kms',
#  '21,231 Kms',
#  '15,900 Kms',
#  '6,937 Kms',
#  '38,200 Kms',
#  '20,463 Kms',
#  '46,742 Kms',
# ...

# %%
owners=[]
for i in car_urls:
    driver.get(i)
    time.sleep(2)
    try:
        no=driver.find_elements_by_xpath('//*[@id="rf01"]/div[1]/div/div/main/div/div/div[1]/div[3]/div/div/div/ul/li[6]/div/div[2]')
        for i in no:
            owners.append(i.text)
    except NoSuchElementException:
        owners.append('-')
owners
# Out:
# ['1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
# ...

# %%
model_year=[]
for i in car_urls:
    driver.get(i)
    time.sleep(2)
    try:
        Brand=driver.find_elements_by_xpath('//*[@id="rf01"]/div[1]/div/div/main/div/div/div[1]/div[3]/div/div/div/ul/li[1]/div/div[2]')
        for i in Brand:
            model_year.append(i.text)
    except NoSuchElementException:
        model_year.append('-')
model_year
# Out:
# ['2018',
#  '2019',
#  '2013',
#  '2019',
#  '2017',
#  '2018',
#  '2019',
#  '2018',
#  '2014',
#  '2018',
#  '2016',
#  '2017',
#  '2017',
#  '2019',
#  '2018',
#  '2015',
#  '2017',
#  '2019',
#  '2015',
#  '2020',
#  '2016',
#  '2018',
#  '2012',
#  '2019',
#  '2015',
#  '2015',
#  '2019',
#  '2018',
#  '2018',
#  '2018',
#  '2012',
#  '2019',
#  '2017',
#  '2016',
#  '2020',
#  '2018',
#  '2016',
#  '2018',
#  '2016',
#  '2015',
#  '2016',
#  '2018',
#  '2012',
#  '2019',
#  '2015',
#  '2015',
#  '2019',
#  '2018',
#  '2018',
#  '2018',
#  '2012',
#  '2019',
#  '2017',
#  '2016',
#  '2020',
#  '2018',
#  '2016',
#  '2018',
#  '2016',
#  '2015',
#  '2018',
#  '2018',
#  '2015',
#  '2015',
#  '2015',
#  '2018',
#  '2014',
#  '2017',
#  '2020',
#  '2017',
#  '2019',
#  '2019',
#  '2019',
#  '2011',
#  '2018',
#  '2017',
#  '2017',
#  '2017',
#  '2016',
#  '2017',
#  '2016',
#  '2017',
#  '2014',
#  '2016',
#  '2015',
#  '2016',
#  '2017',
#  '2016',
#  '2017',
#  '2016',
# ...

# %%
fuel_type=[]
for i in car_urls:
    driver.get(i)
    time.sleep(2)
    try:
        type=driver.find_elements_by_xpath('//*[@id="rf01"]/div[1]/div/div/main/div/div/div[1]/div[3]/div/div/div/ul/li[3]/div/div[2]')
        for i in type:
            fuel_type.append(i.text)
    except NoSuchElementException:
        fuel_type.append('-')
fuel_type
# Out:
# ['Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'CNG',
# ...

# %%
len(model),len(model_year),len(fuel_type),len(kilometers),len(owners),len(Price)
# Out:
# (160, 159, 159, 159, 159, 160)

# %%
# creating a pandas dataframe
data2= pd.DataFrame({'website':'cardekho','model':model[:159],'model_year':model_year,'fuel-type':fuel_type,'location':'Delhi','driven kilometers':kilometers,'No of owners':owners,'Price':Price[:159]})
  # show the dataframe
data2
# Out:
#       website                   model model_year fuel-type location  \
# 0    cardekho    2018 Maruti Alto K10       2018    Petrol    Delhi
# 1    cardekho         2020 Tata Tiago       2019    Petrol    Delhi
# 2    cardekho    2013 Maruti Alto K10       2013    Petrol    Delhi
# 3    cardekho  2019 Hyundai Grand I10       2019    Petrol    Delhi
# 4    cardekho  2017 Hyundai Grand I10       2017    Diesel    Delhi
# ..        ...                     ...        ...       ...      ...
# 154  cardekho       2016 Maruti Swift       2012    Petrol    Delhi
# 155  cardekho        2012 Hyundai I10       2020    Petrol    Delhi
# 156  cardekho      2020 Hyundai Venue       2015    Petrol    Delhi
# 157  cardekho     2015 Maruti Celerio       2019    Petrol    Delhi
# 158  cardekho        2019 Honda Amaze       2016       CNG    Delhi
#
#     driven kilometers No of owners     Price
# 0          18,819 Kms    1st Owner  3,61,000
# 1           6,947 Kms    1st Owner  5,40,500
# ...

# %%
#getting the url
url = "https://www.cardekho.com/buy-used-cars+in+ahmedabad"
driver.get(url)
time.sleep(2)

# %%
car_urls = []
url=driver.find_elements_by_xpath('//div[@class="gsc_col-xs-6 carsName"]/a')       
for i in url:
    car_urls.append(i.get_attribute("href"))                       
car_urls
# Out:
# ['https://www.cardekho.com/buy-used-car-details/used-Maruti-Eeco-5-Seater-Ac-cars-Ahmedabad_d4d13c2e-cc86-4178-9c6a-0b7c1a4cffc4.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Maruti-Eeco-5-Seater-Ac-cars-Ahmedabad_50626fd6-cd52-486f-8186-1f5dfe248448.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Maruti-Eeco-5-Seater-Ac-cars-Ahmedabad_cf8fe1d6-fee4-4118-9fdb-336f4b43fb79.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Maruti-Eeco-5-Seater-Ac-Bsiv-cars-Ahmedabad_217c68ee-3cc0-469a-89d6-7bfc21c05e65.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Maruti-Eeco-5-Seater-Ac-Bsiv-cars-Ahmedabad_59964dd8-2de6-4dd9-9413-e73918e14b80.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Maruti-Eeco-5-Seater-Ac-cars-Ahmedabad_27a42015-9ccf-4ac5-a927-494a956ba35d.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Maruti-S-presso-Vxi-cars-Ahmedabad_8519418f-ec92-4243-8266-641295a438cc.htm',
# ...

# %%
model=[]
try:
    brand=driver.find_elements_by_xpath('//div[@class="gsc_col-xs-6 carsName"]/a')
    for i in brand:
        model.append(i.text)
except NoSuchElementException:
    model.append('-')
model
# Out:
# ['2012 Maruti Eeco',
#  '2017 Maruti Eeco',
#  '2020 Maruti Eeco',
#  '2019 Maruti Eeco',
#  '2016 Maruti Eeco',
#  '2020 Maruti Eeco',
#  '2019 Maruti S-presso',
#  '2013 Toyota Innova',
#  '2011 Maruti Wagon R',
#  '2013 Maruti Swift Dzire',
#  '2017 Maruti Baleno',
#  '2016 Maruti Baleno',
#  '2016 Ford Ecosport',
#  '2020 Maruti Swift Dzire',
#  '2017 Maruti Baleno',
#  '2020 Maruti Swift Dzire',
#  '2017 Maruti Wagon R',
#  '2016 Maruti Swift',
#  '2019 Maruti Swift',
#  '2018 Maruti Swift',
#  '2014 Maruti Wagon R',
#  '2014 Maruti Wagon R',
#  '2020 Maruti Wagon R',
#  '2015 Maruti Swift Dzire',
#  '2014 Maruti Wagon R',
#  '2016 Nissan Terrano',
#  '2013 Maruti Swift',
#  '2019 Volkswagen Vento',
#  '2017 Maruti Wagon R',
#  '2014 Hyundai Verna',
#  '2015 Hyundai Grand I10',
#  '2018 Honda Amaze',
#  '2018 Honda City',
#  '2011 Honda City',
#  '2019 Maruti Swift Dzire',
#  '2016 Maruti Wagon R',
#  '2012 Maruti Alto K10']

# %%
Price=[]
try:
    price=driver.find_elements_by_xpath('//span[@class="amnt "]')
    for i in price:
        Price.append(i.text)
except NoSuchElementException:
    Price.append('-')
Price
# Out:
# ['2,79,000',
#  '3,97,000',
#  '4,72,000',
#  '4,57,000',
#  '3,80,500',
#  '4,69,500',
#  '4,22,000',
#  '6,70,500',
#  '2,67,500',
#  '3,40,500',
#  '6,10,000',
#  '4,82,500',
#  '5,89,500',
#  '6,95,000',
#  '5,35,500',
#  '6,83,500',
#  '3,87,000',
#  '4,64,000',
#  '6,00,000',
#  '5,85,000',
#  '2,94,500',
#  '2,79,500',
#  '5,06,500',
#  '4,91,500',
#  '3,28,500',
#  '4,70,500',
#  '3,99,000',
#  '7,11,000',
#  '4,30,000',
#  '5,43,000',
#  '4,80,500',
#  '5,01,500',
#  '7,63,500',
#  '3,99,500',
#  '6,65,000',
#  '3,60,000',
#  '1,77,500']

# %%
kilometers=[]
for i in car_urls:
    driver.get(i)
    time.sleep(2)
    try:
        kms=driver.find_elements_by_xpath('//*[@id="rf01"]/div[1]/div/div/main/div/div/div[1]/div[3]/div/div/div/ul/li[4]/div/div[2]')
        for i in kms:
            kilometers.append(i.text)
    except NoSuchElementException:
        kilometers.append('-')
kilometers
# Out:
# ['57,341 Kms',
#  '88,362 Kms',
#  '17,116 Kms',
#  '14,161 Kms',
#  '45,347 Kms',
#  '19,627 Kms',
#  '24,230 Kms',
#  '94,754 Kms',
#  '60,689 Kms',
#  '80,084 Kms',
#  '49,072 Kms',
#  '51,069 Kms',
#  '42,029 Kms',
#  '11,935 Kms',
#  '34,669 Kms',
#  '9,303 Kms',
#  '43,031 Kms',
#  '45,090 Kms',
#  '21,060 Kms',
#  '31,694 Kms',
#  '131,125 Kms',
#  '85,416 Kms',
#  '10,371 Kms',
#  '54,419 Kms',
#  '42,381 Kms',
#  '74,431 Kms',
#  '72,301 Kms',
#  '97,922 Kms',
#  '41,174 Kms',
#  '65,484 Kms',
#  '73,875 Kms',
#  '59,642 Kms',
#  '89,144 Kms',
#  '38,647 Kms',
#  '9,718 Kms',
#  '81,674 Kms',
#  '89,579 Kms']

# %%
owners=[]
for i in car_urls:
    driver.get(i)
    time.sleep(2)
    try:
        no=driver.find_elements_by_xpath('//*[@id="rf01"]/div[1]/div/div/main/div/div/div[1]/div[3]/div/div/div/ul/li[6]/div/div[2]')
        for i in no:
            owners.append(i.text)
    except NoSuchElementException:
        owners.append('-')
owners
# Out:
# ['1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner']

# %%
model_year=[]
for i in car_urls:
    driver.get(i)
    time.sleep(2)
    try:
        Brand=driver.find_elements_by_xpath('//*[@id="rf01"]/div[1]/div/div/main/div/div/div[1]/div[3]/div/div/div/ul/li[1]/div/div[2]')
        for i in Brand:
            model_year.append(i.text)
    except NoSuchElementException:
        model_year.append('-')
model_year
# Out:
# ['2012',
#  '2017',
#  '2020',
#  '2019',
#  '2016',
#  '2020',
#  '2019',
#  '2013',
#  '2011',
#  '2012',
#  '2017',
#  '2016',
#  '2016',
#  '2019',
#  '2017',
#  '2019',
#  '2017',
#  '2016',
#  '2019',
#  '2018',
#  '2014',
#  '2013',
#  '2020',
#  '2015',
#  '2014',
#  '2016',
#  '2013',
#  '2018',
#  '2017',
#  '2014',
#  '2015',
#  '2017',
#  '2018',
#  '2011',
#  '2019',
#  '2016',
#  '2012']

# %%
fuel_type=[]
for i in car_urls:
    driver.get(i)
    time.sleep(2)
    try:
        type=driver.find_elements_by_xpath('//*[@id="rf01"]/div[1]/div/div/main/div/div/div[1]/div[3]/div/div/div/ul/li[3]/div/div[2]')
        for i in type:
            fuel_type.append(i.text)
    except NoSuchElementException:
        fuel_type.append('-')
fuel_type
# Out:
# ['Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol']

# %%
# creating a pandas dataframe
data3= pd.DataFrame({'website':'Cardekho','model':model,'model_year':model_year,'fuel-type':fuel_type,'location':'Ahmedabad','driven kilometers':kilometers,'No of owners':owners,'Price':Price})
  # show the dataframe
data3
# Out:
#      website                    model model_year fuel-type   location  \
# 0   Cardekho         2012 Maruti Eeco       2012    Petrol  Ahmedabad
# 1   Cardekho         2017 Maruti Eeco       2017    Petrol  Ahmedabad
# 2   Cardekho         2020 Maruti Eeco       2020    Petrol  Ahmedabad
# 3   Cardekho         2019 Maruti Eeco       2019    Petrol  Ahmedabad
# 4   Cardekho         2016 Maruti Eeco       2016    Petrol  Ahmedabad
# 5   Cardekho         2020 Maruti Eeco       2020    Petrol  Ahmedabad
# 6   Cardekho     2019 Maruti S-presso       2019    Petrol  Ahmedabad
# 7   Cardekho       2013 Toyota Innova       2013    Diesel  Ahmedabad
# 8   Cardekho      2011 Maruti Wagon R       2011    Petrol  Ahmedabad
# 9   Cardekho  2013 Maruti Swift Dzire       2012    Diesel  Ahmedabad
# 10  Cardekho       2017 Maruti Baleno       2017    Petrol  Ahmedabad
# 11  Cardekho       2016 Maruti Baleno       2016    Petrol  Ahmedabad
# ...

# %%
#getting the url
url = "https://www.cardekho.com/buy-used-cars+in+hyderabad"
driver.get(url)
time.sleep(2)

# %%
car_urls = []
url=driver.find_elements_by_xpath('//div[@class="gsc_col-xs-6 carsName"]/a')       
for i in url:
    car_urls.append(i.get_attribute("href"))                       
car_urls
# Out:
# ['https://www.cardekho.com/buy-used-car-details/used-Maruti-Alto-800-Vxi-Optional-cars-Hyderabad_ad9432b9-122e-4d23-ae79-61e7a6e7a2a7.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Maruti-Celerio-X-Amt-Zxi-Option-Bsiv-cars-Hyderabad_e58742cb-7e1a-4c99-9ff1-338b4f3b77d4.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Hyundai-Santro-Asta-cars-Hyderabad_1872e955-cb42-4caa-82ce-dd1d3b59b47b.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Maruti-Swift-Vxi-Glory-Limited-Edition-cars-Hyderabad_105017bc-48c8-48ee-ac12-32a8273b015c.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Maruti-Ignis-1.3-Alpha-cars-Hyderabad_e39fe8f1-7fbb-450d-ad77-e9710d385637.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Hyundai-Grand-I10-1.2-Kappa-Magna-Bsiv-cars-Hyderabad_afb067fc-4b5a-44a9-ab97-ec596f08ccf8.htm',
# ...

# %%
model=[]
try:
    brand=driver.find_elements_by_xpath('//div[@class="gsc_col-xs-6 carsName"]/a')
    for i in brand:
        model.append(i.text)
except NoSuchElementException:
    model.append('-')
model
# Out:
# ['2016 Maruti Alto 800',
#  '2018 Maruti Celerio X',
#  '2019 Hyundai Santro',
#  '2016 Maruti Swift',
#  '2017 Maruti Ignis',
#  '2018 Hyundai Grand I10',
#  '2017 Hyundai Grand I10',
#  '2018 Maruti Alto 800',
#  '2019 Hyundai I20',
#  '2019 Hyundai Grand I10',
#  '2016 Maruti Alto 800',
#  '2016 Honda Jazz',
#  '2018 Maruti Alto 800',
#  '2017 Hyundai Grand I10',
#  '2013 Maruti Ritz',
#  '2016 Maruti Alto 800',
#  '2019 Hyundai Grand I10',
#  '2017 Honda Jazz',
#  '2019 Hyundai Grand I10',
#  '2020 Hyundai Santro',
#  '2019 Hyundai Grand I10',
#  '2017 Hyundai Grand I10',
#  '2020 Hyundai Grand I10',
#  '2018 Maruti Ignis',
#  '2015 Volkswagen Polo',
#  '2019 Maruti Alto 800',
#  '2017 Hyundai Grand I10',
#  '2015 Hyundai Grand I10',
#  '2016 Volkswagen Polo',
#  '2018 Volkswagen Polo',
#  '2016 Maruti Omni',
#  '2019 Maruti Omni',
#  '2017 Hyundai Grand I10',
#  '2019 Volkswagen Polo',
#  '2016 Hyundai I20',
#  '2020 Maruti Celerio',
#  '2015 Maruti Alto 800',
# ...

# %%
Price=[]
try:
    price=driver.find_elements_by_xpath('//span[@class="amnt "]')
    for i in price:
        Price.append(i.text)
except NoSuchElementException:
    Price.append('-')
Price
# Out:
# ['3,53,500',
#  '5,35,500',
#  '5,44,000',
#  '5,35,980',
#  '5,66,000',
#  '5,54,312',
#  '6,10,202',
#  '3,34,500',
#  '6,91,364',
#  '5,50,000',
#  '2,78,000',
#  '5,68,500',
#  '3,52,500',
#  '5,12,500',
#  '3,96,000',
#  '2,95,000',
#  '6,11,444',
#  '7,30,387',
#  '5,31,000',
#  '5,59,051',
#  '6,16,500',
#  '4,64,500',
#  '6,99,500',
#  '4,79,000',
#  '5,57,000',
#  '3,49,500',
#  '5,74,500',
#  '4,87,000',
#  '5,58,000',
#  '6,97,000',
#  '2,22,000',
#  '3,56,500',
#  '5,51,327',
#  '6,10,500',
#  '5,72,500',
#  '5,32,000',
#  '2,80,000',
#  '5,80,000',
#  '5,42,000',
#  '7,34,000',
#  '5,54,500',
#  '5,97,500',
#  '5,64,000',
#  '6,22,203',
#  '4,51,500',
#  '7,57,000',
#  '6,98,185',
#  '6,76,000',
#  '4,03,000',
#  '6,59,500',
#  '5,15,000',
#  '5,70,000',
#  '6,93,000',
#  '7,12,000',
#  '6,91,000',
#  '4,65,500',
#  '6,42,500',
#  '6,13,500',
#  '6,46,000',
#  '5,56,000',
#  '5,69,000',
#  '3,86,500',
#  '4,61,500',
#  '4,77,500',
#  '7,11,500',
#  '6,82,000',
# ...

# %%
kilometers=[]
for i in car_urls:
    driver.get(i)
    time.sleep(2)
    try:
        kms=driver.find_elements_by_xpath('//*[@id="rf01"]/div[1]/div/div/main/div/div/div[1]/div[3]/div/div/div/ul/li[4]/div/div[2]')
        for i in kms:
            kilometers.append(i.text)
    except NoSuchElementException:
        kilometers.append('-')
kilometers
# Out:
# ['17,160 Kms',
#  '14,242 Kms',
#  '29,892 Kms',
#  '31,278 Kms',
#  '68,201 Kms',
#  '13,732 Kms',
#  '500 Kms',
#  '16,327 Kms',
#  '33,894 Kms',
#  '12,757 Kms',
#  '66,564 Kms',
#  '29,526 Kms',
#  '14,675 Kms',
#  '36,231 Kms',
#  '84,203 Kms',
#  '71,553 Kms',
#  '33,580 Kms',
#  '17,784 Kms',
#  '13,823 Kms',
#  '13,767 Kms',
#  '4,941 Kms',
#  '64,796 Kms',
#  '14,369 Kms',
#  '25,097 Kms',
#  '98,265 Kms',
#  '30,392 Kms',
#  '50,416 Kms',
#  '14,720 Kms',
#  '99,555 Kms',
#  '500 Kms',
#  '29,156 Kms',
#  '3,071 Kms',
#  '28,228 Kms',
#  '24,556 Kms',
#  '85,071 Kms',
#  '22,997 Kms',
#  '44,193 Kms',
#  '3,478 Kms',
#  '8,662 Kms',
#  '33,579 Kms',
#  '82,432 Kms',
#  '22,208 Kms',
#  '36,878 Kms',
#  '60,956 Kms',
#  '43,259 Kms',
#  '74,031 Kms',
#  '10,385 Kms',
#  '500 Kms',
#  '500 Kms',
#  '8,482 Kms',
#  '17,335 Kms',
#  '34,782 Kms',
#  '13,071 Kms',
#  '11,707 Kms',
#  '38,197 Kms',
#  '75,925 Kms',
#  '46,396 Kms',
#  '36,568 Kms',
#  '30,053 Kms',
# ...

# %%
owners=[]
for i in car_urls:
    driver.get(i)
    time.sleep(2)
    try:
        no=driver.find_elements_by_xpath('//*[@id="rf01"]/div[1]/div/div/main/div/div/div[1]/div[3]/div/div/div/ul/li[6]/div/div[2]')
        for i in no:
            owners.append(i.text)
    except NoSuchElementException:
        owners.append('-')
owners
# Out:
# ['1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
# ...

# %%
model_year=[]
for i in car_urls:
    driver.get(i)
    time.sleep(2)
    try:
        Brand=driver.find_elements_by_xpath('//*[@id="rf01"]/div[1]/div/div/main/div/div/div[1]/div[3]/div/div/div/ul/li[1]/div/div[2]')
        for i in Brand:
            model_year.append(i.text)
    except NoSuchElementException:
        model_year.append('-')
model_year
# Out:
# ['2016',
#  '2018',
#  '2019',
#  '2015',
#  '2017',
#  '2018',
#  '2017',
#  '2018',
#  '2019',
#  '2019',
#  '2016',
#  '2016',
#  '2018',
#  '2016',
#  '2013',
#  '2015',
#  '2018',
#  '2017',
#  '2019',
#  '2019',
#  '2019',
#  '2016',
#  '2019',
#  '2018',
#  '2015',
#  '2019',
#  '2016',
#  '2015',
#  '2015',
#  '2017',
#  '2015',
#  '2018',
#  '2017',
#  '2019',
#  '2016',
#  '2019',
#  '2015',
#  '2019',
#  '2017',
#  '2017',
#  '2014',
#  '2015',
#  '2015',
#  '2017',
#  '2015',
#  '2018',
#  '2018',
#  '2018',
#  '2015',
#  '2018',
#  '2018',
#  '2015',
#  '2018',
#  '2018',
#  '2019',
#  '2019',
#  '2017',
#  '2016',
#  '2018',
#  '2016',
#  '2014',
#  '2015',
#  '2015',
#  '2015',
#  '2018',
#  '2017',
#  '2017',
#  '2014',
#  '2018',
#  '2019',
#  '2019',
#  '2013',
#  '2012',
#  '2014',
#  '2016',
#  '2014',
#  '2017',
#  '2017',
#  '2015',
#  '2018',
#  '2011',
#  '2012',
#  '2018',
#  '2014',
#  '2018',
#  '2018',
#  '2016',
#  '2018',
#  '2017',
#  '2013',
# ...

# %%
fuel_type=[]
for i in car_urls:
    driver.get(i)
    time.sleep(2)
    try:
        type=driver.find_elements_by_xpath('//*[@id="rf01"]/div[1]/div/div/main/div/div/div[1]/div[3]/div/div/div/ul/li[3]/div/div[2]')
        for i in type:
            fuel_type.append(i.text)
    except NoSuchElementException:
        fuel_type.append('-')
fuel_type
# Out:
# ['Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'CNG',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Petrol',
# ...

# %%
# creating a pandas dataframe
data5= pd.DataFrame({'website':'Cardekho','model':model,'model_year':model_year,'fuel-type':fuel_type,'location':'Hyderabad','driven kilometers':kilometers,'No of owners':owners,'Price':Price})
  # show the dataframe
data5
# Out:
#       website                      model model_year fuel-type   location  \
# 0    Cardekho       2016 Maruti Alto 800       2016    Petrol  Hyderabad
# 1    Cardekho      2018 Maruti Celerio X       2018    Petrol  Hyderabad
# 2    Cardekho        2019 Hyundai Santro       2019    Petrol  Hyderabad
# 3    Cardekho          2016 Maruti Swift       2015    Petrol  Hyderabad
# 4    Cardekho          2017 Maruti Ignis       2017    Diesel  Hyderabad
# ..        ...                        ...        ...       ...        ...
# 132  Cardekho     2020 Hyundai Grand I10       2019    Petrol  Hyderabad
# 133  Cardekho      2016 Ford Figo Aspire       2016    Petrol  Hyderabad
# 134  Cardekho           2016 Hyundai I10       2015    Petrol  Hyderabad
# 135  Cardekho  2020 Maruti Vitara Brezza       2020    Petrol  Hyderabad
# 136  Cardekho           2020 Tata Altroz       2020    Petrol  Hyderabad
#
#     driven kilometers No of owners     Price
# 0          17,160 Kms    1st Owner  3,53,500
# ...

# %%
#getting the url
url = "https://www.cardekho.com/buy-used-cars+in+jaipur"
driver.get(url)
time.sleep(2)

# %%
car_urls = []
url=driver.find_elements_by_xpath('//div[@class="gsc_col-xs-6 carsName"]/a')       
for i in url:
    car_urls.append(i.get_attribute("href"))                       
car_urls
# Out:
# ['https://www.cardekho.com/buy-used-car-details/used-Ford-Ecosport-1.5-Diesel-Titanium-Plus-cars-Jaipur_1a8a07f4-febf-4243-939a-b53405e4162a.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Hyundai-Grand-I10-1.2-Crdi-Asta-cars-Jaipur_aed0c8b7-f5bb-4f7b-9a44-9faec7fe46b7.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Hyundai-Grand-I10-Asta-cars-Jaipur_e577318b-f0a9-4ed6-9d8d-00b77fd75691.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Mercedes-benz-Gle-Class-350d-cars-Jaipur_d33adc47-fc3c-476f-b621-dfa2a4bb785c.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Hyundai-Grand-I10-1.2-Kappa-Sportz-Bsiv-cars-Jaipur_84d30004-3b60-427e-9ba3-d99c83d0c633.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Tata-Tiago-Xz-cars-Jaipur_04d2fc97-17d9-4017-a488-c7fd753e1740.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Hyundai-I10-Sportz-1.1l-cars-Jaipur_85df2579-c46d-43e0-a318-aed23526d913.htm',
# ...

# %%
model=[]
try:
    brand=driver.find_elements_by_xpath('//div[@class="gsc_col-xs-6 carsName"]/a')
    for i in brand:
        model.append(i.text)
except NoSuchElementException:
    model.append('-')
model
# Out:
# ['2017 Ford Ecosport',
#  '2019 Hyundai Grand I10',
#  '2016 Hyundai Grand I10',
#  '2015 Mercedes-benz Gle Class',
#  '2016 Hyundai Grand I10',
#  '2018 Tata Tiago',
#  '2014 Hyundai I10',
#  '2017 Hyundai I20',
#  '2013 Volkswagen Polo',
#  '2015 Maruti Alto K10',
#  '2019 Mg Hector',
#  '2011 Maruti Swift Dzire',
#  '2017 Maruti Vitara Brezza',
#  '2019 Hyundai Verna',
#  '2016 Hyundai Creta',
#  '2018 Mahindra Xuv500',
#  '2019 Hyundai I20',
#  '2018 Maruti Alto 800',
#  '2016 Hyundai Grand I10',
#  '2018 Maruti Baleno',
#  '2019 Maruti Baleno',
#  '2017 Maruti Ignis',
#  '2019 Maruti S-presso',
#  '2017 Hyundai Grand I10',
#  '2018 Hyundai Grand I10',
#  '2016 Maruti Baleno',
#  '2019 Maruti Baleno',
#  '2017 Hyundai Grand I10',
#  '2013 Maruti Swift',
#  '2014 Toyota Etios Liva',
#  '2017 Hyundai Grand I10',
#  '2019 Maruti S-presso',
#  '2018 Maruti Baleno',
#  '2019 Hyundai Santro',
#  '2018 Maruti Alto 800',
#  '2020 Maruti Baleno',
#  '2018 Maruti Baleno',
# ...

# %%
Price=[]
try:
    price=driver.find_elements_by_xpath('//span[@class="amnt "]')
    for i in price:
        Price.append(i.text)
except NoSuchElementException:
    Price.append('-')
Price
# Out:
# ['8,75,000',
#  '6,70,000',
#  '4,90,000',
#  '38,00,000',
#  '4,65,000',
#  '5,25,000',
#  '3,70,000',
#  '6,75,000',
#  '3,90,000',
#  '3,30,000',
#  '16,50,000',
#  '3,60,000',
#  '8,90,000',
#  '9,75,000',
#  '10,50,000',
#  '15,90,000',
#  '6,90,000',
#  '3,27,452',
#  '4,22,736',
#  '6,20,000',
#  '6,20,000',
#  '4,83,502',
#  '4,22,441',
#  '4,60,011',
#  '4,95,000',
#  '5,21,611',
#  '6,10,000',
#  '4,35,676',
#  '3,99,874',
#  '3,91,000',
#  '4,63,703',
#  '4,40,000',
#  '6,15,000',
#  '4,17,990',
#  '3,24,977',
#  '6,70,000',
#  '6,10,000',
#  '10,15,000',
#  '5,10,000',
#  '3,09,588',
#  '3,23,940',
#  '3,73,156',
#  '5,10,000',
#  '4,26,631',
#  '10,66,985',
#  '4,65,000',
#  '4,96,879',
#  '4,07,885',
#  '5,16,528',
#  '3,90,000',
#  '5,38,615',
#  '3,12,322',
#  '4,58,526',
#  '2,89,697',
#  '3,38,787',
#  '5,51,000',
#  '4,81,001',
#  '6,19,280',
#  '6,45,000',
#  '5,10,000',
#  '3,21,180',
#  '4,15,104',
#  '4,62,153',
#  '9,17,000',
#  '4,47,075',
#  '2,88,400',
# ...

# %%
kilometers=[]
for i in car_urls:
    driver.get(i)
    time.sleep(2)
    try:
        kms=driver.find_elements_by_xpath('//*[@id="rf01"]/div[1]/div/div/main/div/div/div[1]/div[3]/div/div/div/ul/li[4]/div/div[2]')
        for i in kms:
            kilometers.append(i.text)
    except NoSuchElementException:
        kilometers.append('-')
kilometers
# Out:
# ['47,608 Kms',
#  '11,481 Kms',
#  '33,124 Kms',
#  '50,000 Kms',
#  '40,158 Kms',
#  '27,401 Kms',
#  '38,688 Kms',
#  '14,000 Kms',
#  '65,001 Kms',
#  '45,751 Kms',
#  '11,000 Kms',
#  '102,000 Kms',
#  '25,598 Kms',
#  '48,013 Kms',
#  '89,000 Kms',
#  '64,000 Kms',
#  '7,400 Kms',
#  '13,699 Kms',
#  '96,470 Kms',
#  '16,408 Kms',
#  '71,999 Kms',
#  '21,452 Kms',
#  '16,005 Kms',
#  '26,215 Kms',
#  '50,067 Kms',
#  '74,838 Kms',
#  '32,644 Kms',
#  '55,010 Kms',
#  '90,708 Kms',
#  '103,561 Kms',
#  '54,042 Kms',
#  '5,334 Kms',
#  '10,132 Kms',
#  '13,352 Kms',
#  '15,453 Kms',
#  '4,452 Kms',
#  '27,982 Kms',
#  '25,299 Kms',
#  '57,421 Kms',
#  '33,026 Kms',
#  '23,635 Kms',
#  '80,468 Kms',
#  '25,319 Kms',
#  '41,755 Kms',
#  '44,344 Kms',
#  '36,103 Kms',
#  '67,106 Kms',
#  '108,490 Kms',
#  '94,711 Kms',
#  '86,540 Kms',
#  '46,024 Kms',
#  '44,455 Kms',
#  '23,189 Kms',
#  '61,011 Kms',
#  '13,428 Kms',
#  '122,620 Kms',
#  '36,665 Kms',
#  '74,737 Kms',
# ...

# %%
owners=[]
for i in car_urls:
    driver.get(i)
    time.sleep(2)
    try:
        no=driver.find_elements_by_xpath('//*[@id="rf01"]/div[1]/div/div/main/div/div/div[1]/div[3]/div/div/div/ul/li[6]/div/div[2]')
        for i in no:
            owners.append(i.text)
    except NoSuchElementException:
        owners.append('-')
owners
# Out:
# ['1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
# ...

# %%
model_year=[]
for i in car_urls:
    driver.get(i)
    time.sleep(2)
    try:
        Brand=driver.find_elements_by_xpath('//*[@id="rf01"]/div[1]/div/div/main/div/div/div[1]/div[3]/div/div/div/ul/li[1]/div/div[2]')
        for i in Brand:
            model_year.append(i.text)
    except NoSuchElementException:
        model_year.append('-')
model_year
# Out:
# ['2017',
#  '2018',
#  '2016',
#  '2015',
#  '2016',
#  '2018',
#  '2014',
#  '2017',
#  '2013',
#  '2015',
#  '2019',
#  '2011',
#  '2017',
#  '2017',
#  '2016',
#  '2018',
#  '2019',
#  '2018',
#  '2016',
#  '2018',
#  '2019',
#  '2017',
#  '2019',
#  '2016',
#  '2018',
#  '2016',
#  '2018',
#  '2016',
#  '2013',
#  '2013',
#  '2017',
#  '2019',
#  '2018',
#  '2019',
#  '2018',
#  '2020',
#  '2018',
#  '2018',
#  '2016',
#  '2018',
#  '2017',
#  '2015',
#  '2018',
#  '2015',
#  '2019',
#  '2016',
#  '2016',
#  '2015',
#  '2017',
#  '2014',
#  '2016',
#  '2018',
#  '2015',
#  '2017',
#  '2015',
#  '2015',
#  '2018',
#  '2017',
#  '2018',
#  '2015',
#  '2017',
#  '2014',
#  '2019',
#  '2019',
#  '2017',
#  '2009',
#  '2020',
#  '2015',
#  '2016',
#  '2017',
#  '2017',
#  '2018',
#  '2018',
#  '2015',
#  '2020',
#  '2017',
#  '2017',
#  '2017',
#  '2016',
#  '2014',
#  '2018',
#  '2013',
#  '2018',
#  '2014',
#  '2017',
#  '2012',
#  '2017',
#  '2020',
#  '2020',
#  '2017',
# ...

# %%
fuel_type=[]
for i in car_urls:
    driver.get(i)
    time.sleep(2)
    try:
        type=driver.find_elements_by_xpath('//*[@id="rf01"]/div[1]/div/div/main/div/div/div[1]/div[3]/div/div/div/ul/li[3]/div/div[2]')
        for i in type:
            fuel_type.append(i.text)
    except NoSuchElementException:
        fuel_type.append('-')
fuel_type
# Out:
# ['Diesel',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
# ...

# %%
# creating a pandas dataframe
data6= pd.DataFrame({'website':'Cardekho','model':model,'model_year':model_year,'fuel-type':fuel_type,'location':'Jaipur','driven kilometers':kilometers,'No of owners':owners,'Price':Price})
  # show the dataframe
data6
# Out:
#       website                         model model_year fuel-type location  \
# 0    Cardekho            2017 Ford Ecosport       2017    Diesel   Jaipur
# 1    Cardekho        2019 Hyundai Grand I10       2018    Diesel   Jaipur
# 2    Cardekho        2016 Hyundai Grand I10       2016    Petrol   Jaipur
# 3    Cardekho  2015 Mercedes-benz Gle Class       2015    Diesel   Jaipur
# 4    Cardekho        2016 Hyundai Grand I10       2016    Petrol   Jaipur
# ..        ...                           ...        ...       ...      ...
# 161  Cardekho            2016 Ford Ecosport       2015    Diesel   Jaipur
# 162  Cardekho         2017 Mahindra Scorpio       2017    Diesel   Jaipur
# 163  Cardekho             2019 Tata Harrier       2019    Diesel   Jaipur
# 164  Cardekho          2020 Maruti Alto 800       2020    Petrol   Jaipur
# 165  Cardekho        2017 Hyundai Grand I10       2017    Petrol   Jaipur
#
#     driven kilometers No of owners      Price
# ...

# %%
#getting the url
url = "https://www.cardekho.com/buy-used-car|s+in+mumbai"
driver.get(url)
time.sleep(2)

# %%
car_urls = []
url=driver.find_elements_by_xpath('//div[@class="gsc_col-xs-6 carsName"]/a')       
for i in url:
    car_urls.append(i.get_attribute("href"))                       
car_urls
# Out:
# ['https://www.cardekho.com/buy-used-car-details/used-Honda-Amaze-S-I-vtech-cars-Mumbai_6b015233-1e69-4e6e-b7dc-117bd255bd70.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Maruti-Wagon-R-Vxi-cars-Mumbai_8f47dec8-6d5e-47a3-985c-4db64f289742.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Hyundai-I20-Sportz-1.2-cars-Mumbai_7c44db94-ccc8-4384-880a-3dcaebe4292e.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Maruti-Celerio-Vxi-cars-Mumbai_05e52a6a-e698-4032-8d41-b74eda558ab8.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Maruti-Wagon-R-Amt-Vxi-cars-Mumbai_b96ad61c-46f6-40fd-ad1b-8f9f352f3d02.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Maruti-Vitara-Brezza-Zdi-cars-Mumbai_0063f1e6-0748-4230-a579-fc881328ae1a.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Hyundai-I20-Sportz-1.2-cars-Mumbai_414e8397-90ce-4515-9b19-23ce2dc5daf9.htm',
# ...

# %%
model=[]
try:
    brand=driver.find_elements_by_xpath('//div[@class="gsc_col-xs-6 carsName"]/a')
    for i in brand:
        model.append(i.text)
except NoSuchElementException:
    model.append('-')
model
# Out:
# ['2015 Honda Amaze',
#  '2017 Maruti Wagon R',
#  '2015 Hyundai I20',
#  '2017 Maruti Celerio',
#  '2017 Maruti Wagon R',
#  '2016 Maruti Vitara Brezza',
#  '2016 Hyundai I20',
#  '2017 Honda Jazz',
#  '2016 Hyundai Verna',
#  '2017 Maruti Swift Dzire',
#  '2016 Maruti Wagon R',
#  '2014 Maruti Wagon R',
#  '2020 Maruti Baleno',
#  '2015 Maruti Celerio',
#  '2016 Maruti Celerio',
#  '2018 Maruti Swift Dzire',
#  '2017 Maruti Swift Dzire',
#  '2016 Honda Jazz',
#  '2015 Maruti Wagon R',
#  '2017 Hyundai Grand I10',
#  '2015 Maruti Celerio',
#  '2017 Maruti Celerio',
#  '2012 Hyundai I20',
#  '2016 Maruti Baleno',
#  '2015 Hyundai Grand I10',
#  '2017 Hyundai I20 Active',
#  '2016 Hyundai Grand I10',
#  '2012 Maruti Ertiga',
#  '2014 Hyundai Grand I10',
#  '2013 Maruti Swift',
#  '2016 Maruti Swift Dzire',
#  '2014 Hyundai Grand I10',
#  '2015 Maruti Swift Dzire',
#  '2019 Maruti Alto 800',
#  '2014 Renault Duster',
#  '2019 Hyundai Santro',
#  '2019 Hyundai Verna',
# ...

# %%
Price=[]
try:
    price=driver.find_elements_by_xpath('//span[@class="amnt "]')
    for i in price:
        Price.append(i.text)
except NoSuchElementException:
    Price.append('-')
Price
# Out:
# ['4,45,000',
#  '4,39,500',
#  '5,62,500',
#  '4,00,000',
#  '4,30,000',
#  '7,80,000',
#  '5,05,000',
#  '4,79,000',
#  '5,59,500',
#  '7,33,000',
#  '3,70,000',
#  '3,63,000',
#  '7,62,000',
#  '3,93,000',
#  '4,29,500',
#  '7,06,500',
#  '6,21,000',
#  '5,67,000',
#  '3,69,500',
#  '4,55,000',
#  '3,96,500',
#  '4,39,000',
#  '3,40,500',
#  '5,69,500',
#  '4,06,500',
#  '5,76,000',
#  '4,67,000',
#  '5,69,500',
#  '3,86,500',
#  '3,11,500',
#  '6,87,000',
#  '3,18,500',
#  '5,55,000',
#  '3,63,000',
#  '4,71,000',
#  '5,06,000',
#  '9,37,000',
#  '4,22,500',
#  '6,90,500',
#  '1,90,500',
#  '4,45,000',
#  '6,05,000',
#  '7,20,500',
#  '5,98,000',
#  '1,41,000',
#  '4,92,500',
#  '5,53,500',
#  '3,84,000',
#  '4,70,000',
#  '5,67,618',
#  '3,11,500',
#  '3,14,000',
#  '5,79,000',
#  '4,95,000',
#  '3,72,500',
#  '2,49,000',
#  '9,07,000',
#  '6,71,500',
#  '5,92,000',
#  '6,75,000',
#  '11,41,000',
#  '3,79,500',
#  '3,92,500',
#  '4,61,000',
#  '4,02,000',
#  '5,39,500',
# ...

# %%
kilometers=[]
for i in car_urls:
    driver.get(i)
    time.sleep(2)
    try:
        kms=driver.find_elements_by_xpath('//*[@id="rf01"]/div[1]/div/div/main/div/div/div[1]/div[3]/div/div/div/ul/li[4]/div/div[2]')
        for i in kms:
            kilometers.append(i.text)
    except NoSuchElementException:
        kilometers.append('-')
kilometers
# Out:
# ['29,709 Kms',
#  '1,782 Kms',
#  '33,507 Kms',
#  '28,176 Kms',
#  '35,386 Kms',
#  '42,561 Kms',
#  '53,551 Kms',
#  '72,471 Kms',
#  '51,009 Kms',
#  '56,029 Kms',
#  '58,472 Kms',
#  '28,734 Kms',
#  '4,203 Kms',
#  '60,086 Kms',
#  '33,818 Kms',
#  '8,949 Kms',
#  '26,717 Kms',
#  '15,359 Kms',
#  '52,492 Kms',
#  '52,806 Kms',
#  '33,630 Kms',
#  '2,492 Kms',
#  '21,239 Kms',
#  '43,605 Kms',
#  '31,884 Kms',
#  '47,113 Kms',
#  '15,295 Kms',
#  '37,780 Kms',
#  '76,026 Kms',
#  '28,801 Kms',
#  '31,652 Kms',
#  '107,803 Kms',
#  '23,131 Kms',
#  '33,126 Kms',
#  '42,118 Kms',
#  '43,994 Kms',
#  '10,749 Kms',
#  '79,613 Kms',
#  '13,790 Kms',
#  '106,533 Kms',
#  '56,548 Kms',
#  '28,226 Kms',
#  '4,953 Kms',
#  '17,992 Kms',
#  '54,164 Kms',
#  '36,985 Kms',
#  '58,122 Kms',
#  '46,848 Kms',
#  '53,148 Kms',
#  '16,155 Kms',
#  '67,325 Kms',
#  '26,219 Kms',
#  '84,730 Kms',
#  '83,522 Kms',
#  '38,171 Kms',
#  '47,079 Kms',
#  '4,176 Kms',
#  '53,652 Kms',
#  '41,691 Kms',
# ...

# %%
owners=[]
for i in car_urls:
    driver.get(i)
    time.sleep(2)
    try:
        no=driver.find_elements_by_xpath('//*[@id="rf01"]/div[1]/div/div/main/div/div/div[1]/div[3]/div/div/div/ul/li[6]/div/div[2]')
        for i in no:
            owners.append(i.text)
    except NoSuchElementException:
        owners.append('-')
owners
# Out:
# ['1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
# ...

# %%
model_year=[]
for i in car_urls:
    driver.get(i)
    time.sleep(2)
    try:
        Brand=driver.find_elements_by_xpath('//*[@id="rf01"]/div[1]/div/div/main/div/div/div[1]/div[3]/div/div/div/ul/li[1]/div/div[2]')
        for i in Brand:
            model_year.append(i.text)
    except NoSuchElementException:
        model_year.append('-')
model_year
# Out:
# ['2015',
#  '2017',
#  '2015',
#  '2017',
#  '2017',
#  '2016',
#  '2015',
#  '2016',
#  '2015',
#  '2017',
#  '2016',
#  '2014',
#  '2020',
#  '2015',
#  '2015',
#  '2018',
#  '2017',
#  '2016',
#  '2015',
#  '2017',
#  '2014',
#  '2017',
#  '2012',
#  '2015',
#  '2014',
#  '2017',
#  '2016',
#  '2012',
#  '2013',
#  '2012',
#  '2016',
#  '2014',
#  '2015',
#  '2018',
#  '2014',
#  '2019',
#  '2019',
#  '2013',
#  '2017',
#  '2009',
#  '2013',
#  '2015',
#  '2020',
#  '2019',
#  '2009',
#  '2017',
#  '2014',
#  '2013',
#  '2014',
#  '2018',
#  '2011',
#  '2013',
#  '2017',
#  '2013',
#  '2012',
#  '2011',
#  '2019',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2016',
#  '2013',
#  '2015',
#  '2016',
#  '2015',
#  '2013',
#  '2020',
#  '2016',
#  '2015',
#  '2017',
#  '2018',
#  '2017',
#  '2017',
#  '2016',
#  '2017',
#  '2014',
#  '2015',
#  '2013',
#  '2018',
#  '2016',
#  '2018',
#  '2014',
#  '2017',
#  '2017',
#  '2015',
#  '2015',
#  '2017',
#  '2014',
#  '2016',
# ...

# %%
fuel_type=[]
for i in car_urls:
    driver.get(i)
    time.sleep(2)
    try:
        type=driver.find_elements_by_xpath('//*[@id="rf01"]/div[1]/div/div/main/div/div/div[1]/div[3]/div/div/div/ul/li[3]/div/div[2]')
        for i in type:
            fuel_type.append(i.text)
    except NoSuchElementException:
        fuel_type.append('-')
fuel_type
# Out:
# ['Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'CNG',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'CNG',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
# ...

# %%
# creating a pandas dataframe
data7= pd.DataFrame({'website':'Cardekho','model':model,'model_year':model_year,'fuel-type':fuel_type,'location':'Mumbai','driven kilometers':kilometers,'No of owners':owners,'Price':Price})
  # show the dataframe
data7
# Out:
#       website                    model model_year fuel-type location  \
# 0    Cardekho         2015 Honda Amaze       2015    Petrol   Mumbai
# 1    Cardekho      2017 Maruti Wagon R       2017    Petrol   Mumbai
# 2    Cardekho         2015 Hyundai I20       2015    Petrol   Mumbai
# 3    Cardekho      2017 Maruti Celerio       2017    Petrol   Mumbai
# 4    Cardekho      2017 Maruti Wagon R       2017    Petrol   Mumbai
# ..        ...                      ...        ...       ...      ...
# 195  Cardekho        2014 Maruti Swift       2014    Diesel   Mumbai
# 196  Cardekho      2014 Maruti Wagon R       2014    Petrol   Mumbai
# 197  Cardekho   2015 Hyundai Grand I10       2015    Petrol   Mumbai
# 198  Cardekho      2017 Maruti Wagon R       2016    Petrol   Mumbai
# 199  Cardekho  2016 Maruti Swift Dzire       2015    Petrol   Mumbai
#
#     driven kilometers No of owners     Price
# 0          29,709 Kms    1st Owner  4,45,000
# 1           1,782 Kms    1st Owner  4,39,500
# ...

# %%
#getting the url
url = "https://www.cardekho.com/buy-used-cars+in+pune"
driver.get(url)
time.sleep(2)

# %%
car_urls = []
url=driver.find_elements_by_xpath('//div[@class="gsc_col-xs-6 carsName"]/a')       
for i in url:
    car_urls.append(i.get_attribute("href"))                       
car_urls
# Out:
# ['https://www.cardekho.com/buy-used-car-details/used-Maruti-Celerio-Vxi-At-cars-Pune_7f726318-65bd-4930-8675-81f4cd603055.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Maruti-Alto-K10-Vxi-cars-Pune_fa1b51d3-6a0e-444e-bcc6-1950a35d91f4.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Maruti-Wagon-R-Amt-Vxi-cars-Pune_f3a4cb58-f962-411e-a531-efbeaa14a05b.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Hyundai-Grand-I10-Asta-cars-Pune_f4346337-0545-4d68-9a7b-529c631cfb6d.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Maruti-Wagon-R-Vxi-Bs-Iv-cars-Pune_5cc9a7ac-0b32-41f6-a1ee-2912cd85fd65.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Maruti-Wagon-R-Vxi-Bs-Iv-cars-Pune_b8191e15-bc78-412c-9a55-d19f12d03862.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Maruti-Swift-Dzire-Amt-Zdi-cars-Pune_7ef434cb-96a0-4aed-9662-02fae40d7186.htm',
# ...

# %%
model=[]
try:
    brand=driver.find_elements_by_xpath('//div[@class="gsc_col-xs-6 carsName"]/a')
    for i in brand:
        model.append(i.text)
except NoSuchElementException:
    model.append('-')
model
# Out:
# ['2016 Maruti Celerio',
#  '2018 Maruti Alto K10',
#  '2017 Maruti Wagon R',
#  '2016 Hyundai Grand I10',
#  '2017 Maruti Wagon R',
#  '2016 Maruti Wagon R',
#  '2017 Maruti Swift Dzire',
#  '2017 Maruti Wagon R',
#  '2016 Maruti Wagon R',
#  '2017 Maruti Celerio',
#  '2017 Maruti Ignis',
#  '2014 Maruti Wagon R',
#  '2018 Maruti Alto 800',
#  '2014 Maruti Swift',
#  '2017 Maruti Ignis',
#  '2018 Maruti Ignis',
#  '2014 Maruti Wagon R Stingray',
#  '2017 Hyundai I10',
#  '2017 Hyundai Grand I10',
#  '2016 Maruti Celerio',
#  '2017 Maruti Wagon R',
#  '2020 Maruti Wagon R',
#  '2019 Hyundai Verna',
#  '2016 Maruti Celerio',
#  '2017 Maruti Wagon R',
#  '2015 Maruti Wagon R',
#  '2014 Maruti Wagon R',
#  '2016 Maruti Wagon R',
#  '2017 Maruti Wagon R',
#  '2020 Hyundai Santro',
#  '2019 Maruti Swift',
#  '2016 Hyundai I20',
#  '2016 Maruti Alto 800',
#  '2017 Maruti Wagon R',
#  '2019 Hyundai Santro',
#  '2019 Maruti Alto 800',
#  '2018 Maruti Wagon R',
#  '2015 Honda Jazz',
# ...

# %%
Price=[]
try:
    price=driver.find_elements_by_xpath('//span[@class="amnt "]')
    for i in price:
        Price.append(i.text)
except NoSuchElementException:
    Price.append('-')
Price
# Out:
# ['4,65,000',
#  '3,59,500',
#  '4,62,500',
#  '4,71,000',
#  '4,52,500',
#  '3,89,000',
#  '7,71,500',
#  '4,65,000',
#  '4,27,000',
#  '5,85,000',
#  '5,59,500',
#  '3,61,500',
#  '3,71,000',
#  '5,47,690',
#  '5,40,000',
#  '5,55,855',
#  '3,62,500',
#  '4,55,566',
#  '5,69,152',
#  '4,77,384',
#  '4,44,000',
#  '5,91,500',
#  '9,60,500',
#  '4,70,000',
#  '3,86,000',
#  '4,48,978',
#  '3,79,000',
#  '3,60,500',
#  '4,55,500',
#  '5,91,500',
#  '7,27,500',
#  '5,64,000',
#  '2,87,000',
#  '4,61,000',
#  '5,78,000',
#  '3,26,500',
#  '4,39,000',
#  '5,98,000',
#  '3,70,572',
#  '5,51,000',
#  '5,38,000',
#  '5,59,000',
#  '4,80,000',
#  '3,46,000',
#  '7,05,500',
#  '8,37,500',
#  '8,40,000',
#  '8,43,500',
#  '5,29,500',
#  '4,30,000',
#  '6,33,000',
#  '6,35,000',
#  '3,22,197',
#  '6,89,067',
#  '4,21,000',
#  '7,03,000',
#  '1,62,500',
#  '3,66,000',
#  '10,22,500',
#  '9,85,500',
#  '2,03,000',
#  '2,93,500',
#  '8,57,139',
#  '5,35,500',
#  '7,33,000',
#  '6,88,024',
# ...

# %%
kilometers=[]
for i in car_urls:
    driver.get(i)
    time.sleep(2)
    try:
        kms=driver.find_elements_by_xpath('//*[@id="rf01"]/div[1]/div/div/main/div/div/div[1]/div[3]/div/div/div/ul/li[4]/div/div[2]')
        for i in kms:
            kilometers.append(i.text)
    except NoSuchElementException:
        kilometers.append('-')
kilometers
# Out:
# ['16,719 Kms',
#  '13,625 Kms',
#  '21,719 Kms',
#  '61,631 Kms',
#  '50,296 Kms',
#  '62,550 Kms',
#  '88,486 Kms',
#  '24,273 Kms',
#  '33,021 Kms',
#  '14,896 Kms',
#  '13,483 Kms',
#  '30,153 Kms',
#  '29,433 Kms',
#  '82,641 Kms',
#  '29,584 Kms',
#  '41,446 Kms',
#  '44,389 Kms',
#  '17,429 Kms',
#  '21,390 Kms',
#  '34,892 Kms',
#  '3,430 Kms',
#  '4,610 Kms',
#  '8,103 Kms',
#  '28,488 Kms',
#  '29,722 Kms',
#  '33,968 Kms',
#  '40,632 Kms',
#  '35,851 Kms',
#  '52,758 Kms',
#  '4,521 Kms',
#  '4,797 Kms',
#  '52,795 Kms',
#  '67,531 Kms',
#  '43,192 Kms',
#  '24,296 Kms',
#  '90,516 Kms',
#  '31,380 Kms',
#  '95,101 Kms',
#  '98,867 Kms',
#  '18,124 Kms',
#  '10,563 Kms',
#  '41,696 Kms',
#  '73,029 Kms',
#  '55,059 Kms',
#  '30,329 Kms',
#  '60,710 Kms',
#  '10,265 Kms',
#  '25,877 Kms',
#  '45,370 Kms',
#  '31,683 Kms',
#  '30,914 Kms',
#  '36,418 Kms',
#  '48,233 Kms',
#  '55,510 Kms',
#  '22,967 Kms',
#  '36,612 Kms',
#  '55,564 Kms',
#  '49,785 Kms',
#  '21,829 Kms',
# ...

# %%
owners=[]
for i in car_urls:
    driver.get(i)
    time.sleep(2)
    try:
        no=driver.find_elements_by_xpath('//*[@id="rf01"]/div[1]/div/div/main/div/div/div[1]/div[3]/div/div/div/ul/li[6]/div/div[2]')
        for i in no:
            owners.append(i.text)
    except NoSuchElementException:
        owners.append('-')
owners
# Out:
# ['1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
# ...

# %%
model_year=[]
for i in car_urls:
    driver.get(i)
    time.sleep(2)
    try:
        Brand=driver.find_elements_by_xpath('//*[@id="rf01"]/div[1]/div/div/main/div/div/div[1]/div[3]/div/div/div/ul/li[1]/div/div[2]')
        for i in Brand:
            model_year.append(i.text)
    except NoSuchElementException:
        model_year.append('-')
model_year
# Out:
# ['2016',
#  '2018',
#  '2017',
#  '2015',
#  '2017',
#  '2016',
#  '2017',
#  '2017',
#  '2016',
#  '2017',
#  '2017',
#  '2014',
#  '2018',
#  '2014',
#  '2017',
#  '2017',
#  '2014',
#  '2016',
#  '2016',
#  '2016',
#  '2017',
#  '2020',
#  '2019',
#  '2016',
#  '2016',
#  '2015',
#  '2014',
#  '2016',
#  '2017',
#  '2019',
#  '2018',
#  '2016',
#  '2016',
#  '2017',
#  '2019',
#  '2017',
#  '2018',
#  '2015',
#  '2014',
#  '2018',
#  '2019',
#  '2016',
#  '2015',
#  '2013',
#  '2017',
#  '2017',
#  '2018',
#  '2017',
#  '2015',
#  '2015',
#  '2018',
#  '2017',
#  '2012',
#  '2017',
#  '2016',
#  '2016',
#  '2008',
#  '2011',
#  '2018',
#  '2018',
#  '2009',
#  '2012',
#  '2017',
#  '2016',
#  '2019',
#  '2015',
#  '2018',
#  '2017',
#  '2018',
#  '2020',
#  '2018',
#  '2019',
#  '2018',
#  '2020',
#  '2016',
#  '2020',
#  '2018',
#  '2018',
#  '2019',
#  '2019',
#  '2017',
#  '2019',
#  '2017',
#  '2015',
#  '2012',
#  '2016',
#  '2018',
#  '2013',
#  '2018',
#  '2018',
# ...

# %%
fuel_type=[]
for i in car_urls:
    driver.get(i)
    time.sleep(2)
    try:
        type=driver.find_elements_by_xpath('//*[@id="rf01"]/div[1]/div/div/main/div/div/div[1]/div[3]/div/div/div/ul/li[3]/div/div[2]')
        for i in type:
            fuel_type.append(i.text)
    except NoSuchElementException:
        fuel_type.append('-')
fuel_type
# Out:
# ['Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
# ...

# %%
# creating a pandas dataframe
data8= pd.DataFrame({'website':'Cardekho','model':model,'model_year':model_year,'fuel-type':fuel_type,'location':'Pune','driven kilometers':kilometers,'No of owners':owners,'Price':Price})
  # show the dataframe
data8
# Out:
#       website                   model model_year fuel-type location  \
# 0    Cardekho     2016 Maruti Celerio       2016    Petrol     Pune
# 1    Cardekho    2018 Maruti Alto K10       2018    Petrol     Pune
# 2    Cardekho     2017 Maruti Wagon R       2017    Petrol     Pune
# 3    Cardekho  2016 Hyundai Grand I10       2015    Petrol     Pune
# 4    Cardekho     2017 Maruti Wagon R       2017    Petrol     Pune
# ..        ...                     ...        ...       ...      ...
# 131  Cardekho        2017 Hyundai I20       2016    Petrol     Pune
# 132  Cardekho         2014 Honda City       2014    Petrol     Pune
# 133  Cardekho      2014 Maruti Ertiga       2014    Diesel     Pune
# 134  Cardekho       2015 Maruti Swift       2015    Diesel     Pune
# 135  Cardekho  2016 Hyundai Grand I10       2015    Petrol     Pune
#
#     driven kilometers No of owners     Price
# 0          16,719 Kms    1st Owner  4,65,000
# 1          13,625 Kms    1st Owner  3,59,500
# ...

# %%
#getting the url
url = "https://www.cardekho.com/buy-used-cars+in+gurgaon"
driver.get(url)
time.sleep(2)

# %%
car_urls = []
url=driver.find_elements_by_xpath('//div[@class="gsc_col-xs-6 carsName"]/a')       
for i in url:
    car_urls.append(i.get_attribute("href"))                       
car_urls
# Out:
# ['https://www.cardekho.com/buy-used-car-details/used-Maruti-Swift-Vdi-Bsiv-cars-Gurgaon_bf97cc63-be46-4abf-a31a-16a619201508.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Hyundai-I20-Sportz-1.2-cars-Gurgaon_2e4035c1-b576-4010-a4d6-2a77d2b061eb.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Maruti-Alto-K10-Lxi-cars-Gurgaon_678af441-5b8b-48e2-bee4-cabbf90726bc.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Ford-Ecosport-Ambiente-Diesel-cars-Gurgaon_c3301bd0-5772-4f81-a35c-a03b6fc6712c.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Maruti-Alto-K10-Vxi-cars-Gurgaon_6d7f8b8e-c48d-47b1-92a8-1871e3da306d.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Maruti-Baleno-Sigma-Diesel-cars-Gurgaon_353c8e30-1b06-4dad-abf6-cc70f28dd3aa.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Maruti-Baleno-1.2-Alpha-cars-Gurgaon_bab28cee-7715-4a18-a2ad-8e657cf48048.htm',
# ...

# %%
model=[]
try:
    brand=driver.find_elements_by_xpath('//div[@class="gsc_col-xs-6 carsName"]/a')
    for i in brand:
        model.append(i.text)
except NoSuchElementException:
    model.append('-')
model
# Out:
# ['2016 Maruti Swift',
#  '2016 Hyundai I20',
#  '2019 Maruti Alto K10',
#  '2015 Ford Ecosport',
#  '2018 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2018 Maruti Baleno',
#  '2017 Maruti Vitara Brezza',
#  '2019 Maruti Baleno',
#  '2013 Honda Brio',
#  '2018 Maruti Ignis',
#  '2016 Maruti Celerio',
#  '2013 Honda Brio',
#  '2016 Maruti Swift Dzire',
#  '2015 Toyota Etios Liva',
#  '2019 Maruti Celerio',
#  '2019 Maruti Ignis',
#  '2015 Maruti Baleno',
#  '2019 Maruti Baleno',
#  '2019 Hyundai I20',
#  '2018 Maruti Swift',
#  '2021 Maruti Alto 800',
#  '2016 Maruti Baleno',
#  '2019 Maruti Ignis',
#  '2019 Maruti Ignis',
#  '2018 Hyundai I20',
#  '2018 Maruti Ciaz',
#  '2016 Maruti Wagon R',
#  '2019 Volkswagen Polo',
#  '2017 Maruti Ciaz',
#  '2014 Hyundai I20',
#  '2013 Ford Ecosport',
#  '2017 Maruti Baleno',
#  '2014 Honda Brio',
#  '2020 Maruti S-presso',
#  '2020 Maruti Alto 800',
#  '2020 Maruti Baleno',
#  '2020 Renault Kwid',
#  '2019 Maruti Wagon R',
# ...

# %%
Price=[]
try:
    price=driver.find_elements_by_xpath('//span[@class="amnt "]')
    for i in price:
        Price.append(i.text)
except NoSuchElementException:
    Price.append('-')
Price
# Out:
# ['4,30,000',
#  '5,76,000',
#  '3,78,500',
#  '4,59,780',
#  '3,28,000',
#  '5,56,500',
#  '6,36,500',
#  '6,98,000',
#  '6,55,000',
#  '3,04,000',
#  '4,64,000',
#  '3,90,905',
#  '2,90,220',
#  '5,00,000',
#  '4,29,311',
#  '4,89,112',
#  '5,57,000',
#  '5,36,244',
#  '7,00,801',
#  '6,68,176',
#  '5,39,808',
#  '3,71,000',
#  '5,47,500',
#  '5,05,000',
#  '5,07,000',
#  '5,31,846',
#  '8,44,000',
#  '3,65,500',
#  '5,95,000',
#  '6,98,000',
#  '4,57,500',
#  '5,10,540',
#  '5,44,500',
#  '3,12,000',
#  '4,69,500',
#  '3,83,500',
#  '5,79,000',
#  '3,31,500',
#  '4,24,000',
#  '2,90,500',
#  '2,81,000',
#  '4,31,587',
#  '3,05,000',
#  '6,79,000',
#  '2,85,000',
#  '3,13,500',
#  '4,16,000',
#  '5,15,500',
#  '3,06,000',
#  '6,14,835',
#  '9,06,000',
#  '6,46,920',
#  '6,17,500',
#  '5,65,500',
#  '4,05,500',
#  '5,78,000',
#  '8,02,500',
#  '3,22,000',
#  '4,26,840',
#  '5,68,450',
#  '2,95,618',
#  '7,10,500',
#  '4,00,500',
#  '4,94,000',
#  '2,64,606',
#  '7,25,600',
# ...

# %%
kilometers=[]
for i in car_urls:
    driver.get(i)
    time.sleep(2)
    try:
        kms=driver.find_elements_by_xpath('//*[@id="rf01"]/div[1]/div/div/main/div/div/div[1]/div[3]/div/div/div/ul/li[4]/div/div[2]')
        for i in kms:
            kilometers.append(i.text)
    except NoSuchElementException:
        kilometers.append('-')
kilometers
# Out:
# ['78,623 Kms',
#  '27,045 Kms',
#  '4,383 Kms',
#  '124,052 Kms',
#  '18,075 Kms',
#  '61,659 Kms',
#  '23,484 Kms',
#  '71,848 Kms',
#  '27,729 Kms',
#  '37,526 Kms',
#  '39,393 Kms',
#  '98,756 Kms',
#  '56,363 Kms',
#  '64,352 Kms',
#  '67,058 Kms',
#  '7,347 Kms',
#  '6,179 Kms',
#  '61,931 Kms',
#  '15,413 Kms',
#  '6,642 Kms',
#  '67,922 Kms',
#  '1,877 Kms',
#  '24,290 Kms',
#  '4,878 Kms',
#  '9,024 Kms',
#  '40,661 Kms',
#  '21,160 Kms',
#  '66,058 Kms',
#  '27,886 Kms',
#  '66,729 Kms',
#  '54,445 Kms',
#  '70,802 Kms',
#  '42,924 Kms',
#  '90,158 Kms',
#  '2,293 Kms',
#  '1,067 Kms',
#  '3,996 Kms',
#  '11,477 Kms',
#  '22,104 Kms',
#  '73,016 Kms',
#  '47,311 Kms',
#  '8,852 Kms',
#  '34,854 Kms',
#  '40,049 Kms',
#  '61,562 Kms',
#  '116,238 Kms',
#  '42,564 Kms',
#  '29,867 Kms',
#  '12,125 Kms',
#  '51,752 Kms',
#  '37,901 Kms',
#  '57,729 Kms',
#  '89,510 Kms',
#  '12,136 Kms',
#  '26,600 Kms',
#  '7,173 Kms',
#  '61,500 Kms',
#  '57,263 Kms',
#  '106,169 Kms',
# ...

# %%
owners=[]
for i in car_urls:
    driver.get(i)
    time.sleep(2)
    try:
        no=driver.find_elements_by_xpath('//*[@id="rf01"]/div[1]/div/div/main/div/div/div[1]/div[3]/div/div/div/ul/li[6]/div/div[2]')
        for i in no:
            owners.append(i.text)
    except NoSuchElementException:
        owners.append('-')
owners
# Out:
# ['1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
# ...

# %%
model_year=[]
for i in car_urls:
    driver.get(i)
    time.sleep(2)
    try:
        Brand=driver.find_elements_by_xpath('//*[@id="rf01"]/div[1]/div/div/main/div/div/div[1]/div[3]/div/div/div/ul/li[1]/div/div[2]')
        for i in Brand:
            model_year.append(i.text)
    except NoSuchElementException:
        model_year.append('-')
model_year
# Out:
# ['2015',
#  '2016',
#  '2019',
#  '2015',
#  '2017',
#  '2018',
#  '2018',
#  '2017',
#  '2019',
#  '2012',
#  '2018',
#  '2016',
#  '2012',
#  '2015',
#  '2014',
#  '2019',
#  '2019',
#  '2015',
#  '2019',
#  '2019',
#  '2018',
#  '2020',
#  '2016',
#  '2018',
#  '2019',
#  '2017',
#  '2018',
#  '2016',
#  '2019',
#  '2017',
#  '2014',
#  '2013',
#  '2017',
#  '2014',
#  '2020',
#  '2020',
#  '2020',
#  '2019',
#  '2018',
#  '2015',
#  '2017',
#  '2018',
#  '2017',
#  '2017',
#  '2016',
#  '2012',
#  '2017',
#  '2017',
#  '2017',
#  '2018',
#  '2018',
#  '2016',
#  '2014',
#  '2019',
#  '2017',
#  '2020',
#  '2018',
#  '2012',
#  '2015',
#  '2015',
#  '2013',
#  '2018',
#  '2018',
#  '2018',
#  '2017',
#  '2016',
#  '2018',
#  '2017',
#  '2018',
#  '2015',
#  '2018',
#  '2020',
#  '2018',
#  '2019',
#  '2018',
#  '2019',
#  '2013',
#  '2018',
#  '2018',
#  '2019',
#  '2019',
#  '2017',
#  '2012',
#  '2018',
#  '2013',
#  '2014',
#  '2015',
#  '2017',
#  '2017',
#  '2019',
# ...

# %%
fuel_type=[]
for i in car_urls:
    driver.get(i)
    time.sleep(2)
    try:
        type=driver.find_elements_by_xpath('//*[@id="rf01"]/div[1]/div/div/main/div/div/div[1]/div[3]/div/div/div/ul/li[3]/div/div[2]')
        for i in type:
            fuel_type.append(i.text)
    except NoSuchElementException:
        fuel_type.append('-')
fuel_type
# Out:
# ['Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
# ...

# %%
# creating a pandas dataframe
data9= pd.DataFrame({'website':'Cardekho','model':model,'model_year':model_year,'fuel-type':fuel_type,'location':'gurgaon','driven kilometers':kilometers,'No of owners':owners,'Price':Price})
  # show the dataframe
data9
# Out:
#       website                 model model_year fuel-type location  \
# 0    Cardekho     2016 Maruti Swift       2015    Diesel  gurgaon
# 1    Cardekho      2016 Hyundai I20       2016    Petrol  gurgaon
# 2    Cardekho  2019 Maruti Alto K10       2019    Petrol  gurgaon
# 3    Cardekho    2015 Ford Ecosport       2015    Diesel  gurgaon
# 4    Cardekho  2018 Maruti Alto K10       2017    Petrol  gurgaon
# ..        ...                   ...        ...       ...      ...
# 155  Cardekho      2016 Maruti Ciaz       2016    Diesel  gurgaon
# 156  Cardekho  2015 Maruti Alto K10       2015    Petrol  gurgaon
# 157  Cardekho      2011 Hyundai I10       2011    Petrol  gurgaon
# 158  Cardekho    2015 Ford Ecosport       2015    Diesel  gurgaon
# 159  Cardekho  2019 Maruti Alto 800       2019    Petrol  gurgaon
#
#     driven kilometers No of owners     Price
# 0          78,623 Kms    1st Owner  4,30,000
# 1          27,045 Kms    1st Owner  5,76,000
# ...

# %%
d=pd.concat([data1,data2,data3,data5,data6,data7,data8,data9],ignore_index= True)
d
# Out:
#        website                 model model_year fuel-type   location  \
# 0     Cardekho  2015 Maruti Alto 800       2015    Petrol  Bangalore
# 1     Cardekho   2016 Maruti Celerio       2016    Petrol  Bangalore
# 2     Cardekho   2014 Maruti Celerio       2014    Petrol  Bangalore
# 3     Cardekho      2012 Hyundai I10       2012    Petrol  Bangalore
# 4     Cardekho   2016 Maruti Celerio       2015    Petrol  Bangalore
# ...        ...                   ...        ...       ...        ...
# 1170  Cardekho      2016 Maruti Ciaz       2016    Diesel    gurgaon
# 1171  Cardekho  2015 Maruti Alto K10       2015    Petrol    gurgaon
# 1172  Cardekho      2011 Hyundai I10       2011    Petrol    gurgaon
# 1173  Cardekho    2015 Ford Ecosport       2015    Diesel    gurgaon
# 1174  Cardekho  2019 Maruti Alto 800       2019    Petrol    gurgaon
#
#      driven kilometers No of owners     Price
# 0           42,358 Kms    2nd Owner  2,90,500
# ...

# %% [markdown]
# ### Carwale used cars list

# %%
#getting the url
url = "https://www.carwale.com/used/cars-for-sale"
driver.get(url)
time.sleep(2)

# %%
car_urls = []
url=driver.find_elements_by_id('linkToDetails')       
for i in url:
    car_urls.append(i.get_attribute("href"))                       
car_urls
# Out:
# ['https://www.carwale.com/used/cars-in-indapur/maruti-suzuki-swift/s1609271/?slot=0&rk=1&isP=false',
#  'https://www.carwale.com/used/cars-in-indapur/maruti-suzuki-swift/s1687999/?slot=0&rk=2&isP=false',
#  'https://www.carwale.com/used/cars-in-indapur/maruti-suzuki-celerio/s1711635/?slot=0&rk=3&isP=false',
#  'https://www.carwale.com/used/cars-in-indapur/maruti-suzuki-vitara-brezza/s1681509/?slot=0&rk=4&isP=false',
#  'https://www.carwale.com/used/cars-in-indapur/toyota-innova/s1681617/?slot=0&rk=5&isP=false',
#  'https://www.carwale.com/used/cars-in-indapur/maruti-suzuki-ertiga/s1664531/?slot=0&rk=6&isP=false',
#  'https://www.carwale.com/used/cars-in-indapur/maruti-suzuki-swift/s1733047/?slot=0&rk=7&isP=false',
#  'https://www.carwale.com/used/cars-in-indapur/maruti-suzuki-alto-800/s1703901/?slot=0&rk=8&isP=false',
#  'https://www.carwale.com/used/cars-in-indapur/maruti-suzuki-ertiga/s1623059/?slot=0&rk=9&isP=false',
# ...

# %%
model=[]
try:
    brand=driver.find_elements_by_xpath('//span[@class="spancarname card-detail-block__title-text-with-year"]')
    for i in brand:
        model.append(i.text)
except NoSuchElementException:
    model.append('-')
model
# Out:
# ['Maruti Suzuki Swift LDi',
#  'Maruti Suzuki Swift LDi',
#  'Maruti Suzuki Celerio VXi (O)',
#  'Maruti Suzuki Vitara Brezza VDi',
#  'Toyota Innova 2.5 G 8 STR BS-IV',
#  'Maruti Suzuki Ertiga VDi',
#  'Maruti Suzuki Swift LDi',
#  'Maruti Suzuki Alto LXi (O) CNG [2019-2020]',
#  'Maruti Suzuki Ertiga VXi CNG [2019-2020]',
#  'Maruti Suzuki 1000 AC',
#  'Chevrolet Beat LS Diesel',
#  'Maruti Suzuki Alto LXi BS-III',
#  'Ford Fiesta Titanium+ Diesel [2011-2014]',
#  'Mahindra Scorpio SLE BS-III',
#  'Mahindra Scorpio S5 2WD 9 STR',
#  'Maruti Suzuki Wagon R 1.0 Vxi ABS-Airbag',
#  'Hyundai Getz Prime 1.3 GLS',
#  'Toyota Sera Coupe',
#  'Maruti Suzuki Alto LXi BS-III',
#  'Maruti Suzuki Alto Std',
#  'Toyota Corolla Altis 1.8 G',
#  'Maruti Suzuki Eeco 7 STR [2019-2020]',
#  'Maruti Suzuki Ertiga VXi CNG',
#  'Hyundai i20 Sportz 1.2 BS-IV',
#  'Tata Indigo eCS LX CR4 BS-IV',
#  'Maruti Suzuki Ertiga LDi 1.3 Diesel',
#  'Maruti Suzuki Swift VDi AMT [2018-2019]',
# ...

# %%
Price=[]
try:
    price=driver.find_elements_by_xpath('//span[@class="rupee-lac slprice"]')
    for i in price:
        Price.append(i.text)
except NoSuchElementException:
    Price.append('-')
Price
# Out:
# ['₹ 2 Lakh',
#  '₹ 2 Lakh',
#  '₹ 5 Lakh',
#  '₹ 7.5 Lakh',
#  '₹ 8 Lakh',
#  '₹ 6.25 Lakh',
#  '₹ 2.1 Lakh',
#  '₹ 1.9 Lakh',
#  '₹ 6.5 Lakh',
#  '₹ 3.4 Lakh',
#  '₹ 2.8 Lakh',
#  '₹ 2 Lakh',
#  '₹ 3 Lakh',
#  '₹ 4.5 Lakh',
#  '₹ 13 Lakh',
#  '₹ 2 Lakh',
#  '₹ 1 Lakh',
#  '₹ 15 Lakh',
#  '₹ 1.2 Lakh',
#  '₹ 90,000',
#  '₹ 3 Lakh',
#  '₹ 2.25 Lakh',
#  '₹ 10.64 Lakh',
#  '₹ 2 Lakh',
#  '₹ 2.5 Lakh',
#  '₹ 7.5 Lakh',
#  '₹ 7.5 Lakh',
#  '₹ 2.8 Lakh',
#  '₹ 1 Lakh',
#  '₹ 1.35 Lakh',
#  '₹ 5.25 Lakh',
#  '₹ 90,000',
#  '₹ 6.5 Lakh',
#  '₹ 2.4 Lakh',
#  '₹ 10 Lakh',
#  '₹ 3 Lakh',
#  '₹ 1 Lakh',
#  '₹ 2.25 Lakh',
#  '₹ 1.2 Lakh',
#  '₹ 1.1 Lakh',
#  '₹ 6.8 Lakh',
#  '₹ 2.65 Lakh',
#  '₹ 6 Lakh',
#  '₹ 4 Lakh',
#  '₹ 4.3 Lakh',
#  '₹ 5 Lakh',
#  '₹ 6 Lakh',
#  '₹ 60,000',
#  '₹ 1.25 Lakh',
#  '₹ 3.75 Lakh',
#  '₹ 6.8 Lakh',
#  '₹ 2.65 Lakh',
#  '₹ 6 Lakh',
#  '₹ 6 Lakh',
#  '₹ 4 Lakh',
#  '₹ 5 Lakh',
#  '₹ 4.3 Lakh',
#  '₹ 60,000',
#  '₹ 1.25 Lakh',
#  '₹ 3.75 Lakh',
#  '₹ 3.5 Lakh',
# ...

# %%
model_year=[]
try:
    Brand=driver.find_elements_by_xpath('//span[@class="slYear card-detail-block__title-text-with-year"]')
    for i in Brand:
        model_year.append(i.text)
except NoSuchElementException:
    model_year.append('-')
model_year
# Out:
# ['2007',
#  '2007',
#  '2019',
#  '2016',
#  '2012',
#  '2012',
#  '2007',
#  '2020',
#  '2021',
#  '2003',
#  '2015',
#  '2006',
#  '2012',
#  '2009',
#  '2020',
#  '2011',
#  '2008',
#  '1998',
#  '2006',
#  '2005',
#  '2008',
#  '2021',
#  '2021',
#  '2010',
#  '2018',
#  '2021',
#  '2018',
#  '2016',
#  '2007',
#  '2008',
#  '2016',
#  '2006',
#  '2016',
#  '2012',
#  '2011',
#  '2011',
#  '2005',
#  '2010',
#  '2009',
#  '2007',
#  '2019',
#  '2017',
#  '2016',
#  '2013',
#  '2020',
#  '2010',
#  '2016',
#  '2009',
#  '2011',
#  '2015',
#  '2019',
#  '2017',
#  '2016',
#  '2016',
#  '2013',
#  '2010',
#  '2020',
#  '2009',
#  '2011',
#  '2015',
#  '2016',
#  '2013',
#  '2008',
#  '2018',
#  '2013',
#  '2007',
#  '2010',
#  '2021',
#  '2021',
#  '2010',
#  '2016',
#  '2021',
#  '2020',
#  '2020',
#  '2021',
#  '2016',
#  '2013',
#  '2021',
#  '2010',
#  '2021',
#  '2009']

# %%
kilometers=[]
try:
    kms=driver.find_elements_by_xpath('//span[@class="slkms vehicle-data__item"]')
    for i in kms:
        kilometers.append(i.text)
except NoSuchElementException:
    kilometers.append('-')
kilometers
# Out:
# ['1,56,781 km',
#  '2,00,000 km',
#  '36,000 km',
#  '1,22,000 km',
#  '1,74,300 km',
#  '1,40,000 km',
#  '1,00,000 km',
#  '70,000 km',
#  '9,999 km',
#  '2,003 km',
#  '75,555 km',
#  '1,00,000 km',
#  '1,79,000 km',
#  '58,000 km',
#  '60,000 km',
#  '70,000 km',
#  '80,000 km',
#  '89,953 km',
#  '1,58,000 km',
#  '1,10,000 km',
#  '1,24,000 km',
#  '10,000 km',
#  '1,00,000 km',
#  '1,05,000 km',
#  '10,000 km',
#  '50,000 km',
#  '90,000 km',
#  '30,000 km',
#  '92,000 km',
#  '70,000 km',
#  '75,000 km',
#  '1,30,000 km',
#  '70,000 km',
#  '97,000 km',
#  '60,000 km',
#  '76,000 km',
#  '1,90,000 km',
#  '1,24,000 km',
#  '92,000 km',
#  '2,25,000 km',
#  '10,140 km',
#  '59,000 km',
#  '86,000 km',
#  '60,000 km',
#  '10,000 km',
#  '1,90,000 km',
#  '2,85,000 km',
#  '35,000 km',
#  '1,12,000 km',
#  '82,000 km',
#  '10,140 km',
#  '59,000 km',
#  '86,000 km',
#  '2,85,000 km',
#  '60,000 km',
#  '1,90,000 km',
#  '10,000 km',
#  '35,000 km',
#  '1,12,000 km',
# ...

# %%
fuel_type=[]
try:
    type=driver.find_elements_by_xpath('//span[@class="fuel vehicle-data__item"]')
    for i in type:
        fuel_type.append(i.text)
except NoSuchElementException:
    fuel_type.append('-')
fuel_type
# Out:
# ['Diesel',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'CNG + 1',
#  'CNG + 1',
#  'Petrol',
#  'Diesel + 1',
#  'Petrol + 1',
#  'Diesel + 1',
#  'Diesel + 1',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol + 1',
#  'Petrol',
#  'Petrol',
#  'Petrol + 1',
#  'CNG + 1',
#  'Petrol',
#  'Diesel + 1',
#  'Diesel',
#  'Diesel + 1',
#  'Petrol + 1',
#  'Petrol + 1',
#  'Petrol + 1',
#  'Diesel + 1',
#  'Diesel + 1',
#  'Diesel + 1',
#  'Diesel + 1',
#  'Diesel + 1',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Diesel + 1',
#  'Diesel',
#  'Diesel',
#  'CNG + 1',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel + 1',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'CNG + 1',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol + 1',
#  'Diesel',
#  'Petrol',
#  'Petrol + 1',
#  'Petrol',
#  'Diesel',
#  'Diesel',
# ...

# %%
owners=[]
for i in car_urls:
    driver.get(i)
    time.sleep(2)
    try:
        no=driver.find_elements_by_xpath('//*[@id="overview"]/div/ul/li[9]/div[2]')
        for i in no:
            owners.append(i.text)
    except NoSuchElementException:
        owners.append('-')
owners
# Out:
# ['Third',
#  'Third',
#  'First',
#  'First',
#  'Second',
#  'First',
#  'Third',
#  'First',
#  'First',
#  'First',
#  'Second',
#  'First',
#  'Second',
#  'First',
#  'First',
#  'Third',
#  'Second',
#  'First',
#  'Second',
#  '4 or More',
#  'Second',
#  'First',
#  'Second',
#  'First',
#  'First',
#  'First',
#  'First',
#  'First',
#  'Second',
#  'Second',
#  'Second',
#  'Second',
#  'Second',
#  'Second',
#  'Second',
#  'Second',
#  'Second',
#  'Second',
#  'Third',
#  'First',
#  'First',
#  'Second',
#  'First',
#  'First',
#  'Second',
#  'Second',
#  'Second',
#  'First',
#  'First',
#  'First',
#  'First',
#  'Second',
#  'Second',
#  'First',
#  'Second',
#  'First',
#  'Second',
#  'First',
#  'First',
#  'First',
#  'Second',
#  'Third',
#  'First',
#  'First',
#  'Second',
#  'First',
#  'First',
#  'Second',
#  'First',
#  'First',
#  'First',
#  'First',
#  'Second',
#  'First',
#  'First',
#  'First']

# %%
len(model),len(model_year),len(fuel_type),len(kilometers),len(owners),len(Price)
# Out:
# (81, 81, 81, 81, 76, 81)

# %%
# creating a pandas dataframe
data10= pd.DataFrame({'website':'carwale','model':model[:76],'model_year':model_year[:76],'fuel-type':fuel_type[:76],'location':'Indapur','driven kilometers':kilometers[:76],'No of owners':owners[:76],'Price':Price[:76]})
  # show the dataframe
data10
# Out:
#     website                                  model model_year     fuel-type  \
# 0   carwale                Maruti Suzuki Swift LDi       2007        Diesel
# 1   carwale                Maruti Suzuki Swift LDi       2007        Diesel
# 2   carwale          Maruti Suzuki Celerio VXi (O)       2019        Petrol
# 3   carwale        Maruti Suzuki Vitara Brezza VDi       2016        Diesel
# 4   carwale        Toyota Innova 2.5 G 8 STR BS-IV       2012        Diesel
# ..      ...                                    ...        ...           ...
# 71  carwale       Maruti Suzuki XL6 Zeta MT Petrol       2021    Petrol + 1
# 72  carwale         Renault Triber RXL [2019-2020]       2020    Petrol + 1
# 73  carwale    Maruti Suzuki Ertiga VDi 1.5 Diesel       2020        Diesel
# 74  carwale                  Tata Tigor EV XE Plus       2021  Electric + 1
# 75  carwale  Hyundai Elite i20 Asta 1.2 (O) [2016]       2016        Petrol
#
#    location driven kilometers No of owners        Price
# ...

# %%
for column in data10.columns:
    data10[column]=data10[column].str.replace(r'\W','')
data10
# Out:
#     website                          model model_year  fuel-type location  \
# 0   carwale           MarutiSuzukiSwiftLDi       2007     Diesel  Indapur
# 1   carwale           MarutiSuzukiSwiftLDi       2007     Diesel  Indapur
# 2   carwale        MarutiSuzukiCelerioVXiO       2019     Petrol  Indapur
# 3   carwale    MarutiSuzukiVitaraBrezzaVDi       2016     Diesel  Indapur
# 4   carwale        ToyotaInnova25G8STRBSIV       2012     Diesel  Indapur
# ..      ...                            ...        ...        ...      ...
# 71  carwale    MarutiSuzukiXL6ZetaMTPetrol       2021    Petrol1  Indapur
# 72  carwale       RenaultTriberRXL20192020       2020    Petrol1  Indapur
# 73  carwale  MarutiSuzukiErtigaVDi15Diesel       2020     Diesel  Indapur
# 74  carwale              TataTigorEVXEPlus       2021  Electric1  Indapur
# 75  carwale     HyundaiElitei20Asta12O2016       2016     Petrol  Indapur
#
#    driven kilometers No of owners    Price
# ...

# %% [markdown]
# ### Cars_24 used cars list

# %%
#getting the url
url = "https://www.cars24.com/buy-used-car?sort=P&storeCityId=4709&pinId=560001"
driver.get(url)
time.sleep(2)

# %%
car_urls = []
url=driver.find_elements_by_xpath('//a[@class="_9Ue0B"]')       
for i in url:
    car_urls.append(i.get_attribute("href"))                       
car_urls
# Out:
# ['https://www.cars24.com/buy-used-Hyundai-Santro-Xing-2011-cars-Bengaluru-1024256821/',
#  'https://www.cars24.com/buy-used-Hyundai-Santro-Xing-2011-cars-Bengaluru-1026426024/',
#  'https://www.cars24.com/buy-used-Renault-Kwid-2016-cars-Bengaluru-1029313025/',
#  'https://www.cars24.com/buy-used-Renault-Kwid-2016-cars-Bengaluru-1022941743/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-K10-2011-cars-Bengaluru-1020501749/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-2009-cars-Bengaluru-1025927040/',
#  'https://www.cars24.com/buy-used-Hyundai-i10-2013-cars-Bengaluru-1020067300/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-800-2017-cars-Bengaluru-1021166221/',
#  'https://www.cars24.com/buy-used-Maruti-Celerio-2014-cars-Bengaluru-1024326744/',
#  'https://www.cars24.com/buy-used-Maruti-Eeco-2019-cars-Bengaluru-1028717548/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-800-2017-cars-Bengaluru-1028583843/',
# ...

# %%
model=[]
try:
    brand=driver.find_elements_by_xpath('//h2[@class="_3FpCg"]')
    for i in brand:
        model.append(i.text)
except NoSuchElementException:
    model.append('-')
model
# Out:
# ['2011 Hyundai Santro Xing',
#  '2011 Hyundai Santro Xing',
#  '2016 Renault Kwid',
#  '2016 Renault Kwid',
#  '2011 Maruti Alto K10',
#  '2009 Maruti Alto',
#  '2013 Hyundai i10',
#  '2017 Maruti Alto 800',
#  '2014 Maruti Celerio',
#  '2019 Maruti Eeco',
#  '2017 Maruti Alto 800',
#  '2008 Maruti Alto',
#  '2014 Hyundai Xcent',
#  '2016 Maruti Eeco',
#  '2015 Honda Brio',
#  '2014 Maruti Celerio',
#  '2015 Maruti Celerio',
#  '2020 Maruti S PRESSO',
#  '2014 Hyundai Eon',
#  '2018 Maruti Alto K10',
#  '2016 Hyundai Grand i10',
#  '2015 Maruti Alto K10',
#  '2015 Maruti Alto 800',
#  '2016 Hyundai Grand i10',
#  '2017 Hyundai Eon',
#  '2017 Maruti Alto K10',
#  '2016 Hyundai Grand i10',
#  '2014 Hyundai Eon',
#  '2014 Hyundai Eon',
#  '2015 Hyundai Grand i10',
#  '2016 Maruti Alto 800',
#  '2012 Maruti Alto 800',
#  '2014 Maruti Alto K10',
#  '2010 Chevrolet Beat',
#  '2012 Maruti Eeco',
#  '2014 Maruti Alto K10',
#  '2014 Hyundai Eon',
#  '2016 Maruti Wagon R 1.0',
# ...

# %%
Price=[]
try:
    price=driver.find_elements_by_xpath('//div[@class="_7udZZ"]/span')
    for i in price:
        Price.append(i.text)
except NoSuchElementException:
    Price.append('-')
Price
# Out:
# ['₹2,81,999',
#  '₹3,06,299',
#  '₹3,55,599',
#  '₹3,88,899',
#  '₹2,49,199',
#  '₹2,06,999',
#  '₹4,02,799',
#  '₹3,53,699',
#  '₹4,10,299',
#  '₹4,56,299',
#  '₹3,40,799',
#  '₹1,77,499',
#  '₹4,79,799',
#  '₹3,64,699',
#  '₹4,98,099',
#  '₹4,02,199',
#  '₹4,15,899',
#  '₹4,58,599',
#  '₹3,29,599',
#  '₹4,17,599',
#  '₹5,22,999',
#  '₹2,93,099',
#  '₹3,02,199',
#  '₹5,11,799',
#  '₹3,43,799',
#  '₹3,94,799',
#  '₹5,15,499',
#  '₹2,47,499',
#  '₹2,97,199',
#  '₹4,77,699',
#  '₹3,30,999',
#  '₹2,50,699',
#  '₹3,01,899',
#  '₹1,84,599',
#  '₹3,14,499',
#  '₹3,16,199',
#  '₹3,02,199',
#  '₹3,93,699',
#  '₹4,66,799',
#  '₹4,57,599',
#  '₹4,43,899',
#  '₹3,97,199',
#  '₹2,36,199',
#  '₹4,15,799',
#  '₹4,07,999',
#  '₹2,62,699',
#  '₹4,86,299',
#  '₹3,73,499',
#  '₹2,90,299',
#  '₹5,16,599',
#  '₹2,99,699',
#  '₹2,63,699',
#  '₹3,70,099',
#  '₹4,49,699',
#  '₹4,79,599',
#  '₹3,42,699',
#  '₹5,30,599',
#  '₹2,34,299',
#  '₹4,79,399',
#  '₹2,18,099',
#  '₹1,61,299',
#  '₹4,14,699',
# ...

# %%
fuel_type=[]
try:
    type=driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[3]')
    for i in type:
        fuel_type.append(i.text)
except NoSuchElementException:
    fuel_type.append('-')
fuel_type
# Out:
# ['Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
# ...

# %%
kilometers=[]
try:
    kms=driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[1]')
    for i in kms:
        kilometers.append(i.text)
except NoSuchElementException:
    kilometers.append('-')
kilometers
# Out:
# ['10,252 km',
#  '16,261 km',
#  '6,190 km',
#  '3,350 km',
#  '31,180 km',
#  '38,264 km',
#  '15,548 km',
#  '6,202 km',
#  '13,928 km',
#  '5,711 km',
#  '10,742 km',
#  '45,812 km',
#  '12,270 km',
#  '22,531 km',
#  '4,392 km',
#  '15,222 km',
#  '4,637 km',
#  '8,241 km',
#  '17,166 km',
#  '9,861 km',
#  '18,698 km',
#  '26,140 km',
#  '21,980 km',
#  '13,532 km',
#  '22,418 km',
#  '8,095 km',
#  '5,214 km',
#  '31,287 km',
#  '25,857 km',
#  '19,346 km',
#  '6,489 km',
#  '28,642 km',
#  '34,163 km',
#  '33,225 km',
#  '33,267 km',
#  '40,061 km',
#  '30,303 km',
#  '16,989 km',
#  '26,578 km',
#  '18,546 km',
#  '28,276 km',
#  '9,287 km',
#  '24,679 km',
#  '23,213 km',
#  '27,478 km',
#  '25,985 km',
#  '11,944 km',
#  '33,609 km',
#  '18,405 km',
#  '14,308 km',
#  '43,307 km',
#  '22,219 km',
#  '22,191 km',
#  '22,201 km',
#  '13,941 km',
#  '24,669 km',
#  '16,201 km',
#  '40,911 km',
#  '21,391 km',
#  '32,291 km',
#  '21,822 km',
#  '34,311 km',
#  '39,169 km',
# ...

# %%
owners=[]
try:
    no=driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[2]')
    for i in no:
        owners.append(i.text)
except NoSuchElementException:
    owners.append('-')
owners
# Out:
# ['1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '3rd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '1st Owner',
#  '3rd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
# ...

# %%
# creating a pandas dataframe
data11= pd.DataFrame({'website':'Cars24','model':model,'model_year':model,'fuel-type':fuel_type,'location':'Bangalore','driven kilometers':kilometers,'No of owners':owners,'Price':Price})
  # show the dataframe
data11
# Out:
#     website                      model                 model_year fuel-type  \
# 0    Cars24   2011 Hyundai Santro Xing   2011 Hyundai Santro Xing    Petrol
# 1    Cars24   2011 Hyundai Santro Xing   2011 Hyundai Santro Xing    Petrol
# 2    Cars24          2016 Renault Kwid          2016 Renault Kwid    Petrol
# 3    Cars24          2016 Renault Kwid          2016 Renault Kwid    Petrol
# 4    Cars24       2011 Maruti Alto K10       2011 Maruti Alto K10    Petrol
# ..      ...                        ...                        ...       ...
# 836  Cars24         2016 Skoda Octavia         2016 Skoda Octavia    Petrol
# 837  Cars24           2014 Honda Amaze           2014 Honda Amaze    Diesel
# 838  Cars24       2014 Mahindra Bolero       2014 Mahindra Bolero    Diesel
# 839  Cars24       2012 Mahindra XUV500       2012 Mahindra XUV500    Diesel
# 840  Cars24  2016 Maruti Vitara Brezza  2016 Maruti Vitara Brezza    Diesel
#
# ...

# %%
#getting the url
url = "https://www.cars24.com/buy-used-car?sort=P&storeCityId=2&pinId=110001"
driver.get(url)
time.sleep(2)

# %%
car_urls = []
url=driver.find_elements_by_xpath('//a[@class="_9Ue0B"]')       
for i in url:
    car_urls.append(i.get_attribute("href"))                       
car_urls
# Out:
# ['https://www.cars24.com/buy-used-Nissan-MAGNITE-2021-cars-New-Delhi-1001685303/',
#  'https://www.cars24.com/buy-used-Maruti-Baleno-2020-cars-New-Delhi-2336817942/',
#  'https://www.cars24.com/buy-used-Maruti-IGNIS-2020-cars-Faridabad-1104943044/',
#  'https://www.cars24.com/buy-used-HYUNDAI-NEW-I20-2021-cars-New-Delhi-1006723403/',
#  'https://www.cars24.com/buy-used-Maruti-IGNIS-2020-cars-New-Delhi-1125187206/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-800-2013-cars-New-Delhi-1055227042/',
#  'https://www.cars24.com/buy-used-Maruti-S-PRESSO-2020-cars-New-Delhi-1108486124/',
#  'https://www.cars24.com/buy-used-Hyundai-GRAND-I10-NIOS-2020-cars-Noida-1488790147/',
#  'https://www.cars24.com/buy-used-Maruti-New--Wagon-R-2020-cars-New-Delhi-1001646140/',
#  'https://www.cars24.com/buy-used-Maruti-S-PRESSO-2020-cars-New-Delhi-1003019901/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-800-2014-cars-New-Delhi-1057739946/',
# ...

# %%
model=[]
try:
    brand=driver.find_elements_by_xpath('//h2[@class="_3FpCg"]')
    for i in brand:
        model.append(i.text)
except NoSuchElementException:
    model.append('-')
model
# Out:
# ['2021 Nissan MAGNITE',
#  '2020 Maruti Baleno',
#  '2020 Maruti IGNIS',
#  '2021 HYUNDAI NEW I20',
#  '2020 Maruti IGNIS',
#  '2013 Maruti Alto 800',
#  '2020 Maruti S PRESSO',
#  '2020 Hyundai GRAND I10 NIOS',
#  '2020 Maruti New Wagon-R',
#  '2020 Maruti S PRESSO',
#  '2014 Maruti Alto 800',
#  '2010 Maruti Alto',
#  '2016 Maruti Celerio',
#  '2021 Hyundai VENUE',
#  '2019 Renault TRIBER',
#  '2013 Maruti Swift',
#  '2020 Maruti Baleno',
#  '2016 Maruti Celerio',
#  '2011 Toyota Corolla Altis',
#  '2019 Maruti Celerio',
#  '2013 Hyundai Santro Xing',
#  '2014 Hyundai Santro Xing',
#  '2015 Hyundai Eon',
#  '2014 Hyundai Grand i10',
#  '2014 Honda Brio',
#  '2017 Maruti Alto K10',
#  '2020 Tata Tiago',
#  '2015 Hyundai Eon',
#  '2015 Maruti Baleno',
#  '2011 Maruti Alto K10',
#  '2011 Volkswagen Polo',
#  '2013 Maruti Swift',
#  '2011 Maruti Zen Estilo',
#  '2015 Maruti Alto 800',
#  '2017 Hyundai Grand i10',
#  '2019 Renault Kwid',
#  '2020 Maruti Alto',
# ...

# %%
Price=[]
try:
    price=driver.find_elements_by_xpath('//div[@class="_7udZZ"]/span')
    for i in price:
        Price.append(i.text)
except NoSuchElementException:
    Price.append('-')
Price
# Out:
# ['₹8,05,000',
#  '₹6,45,199',
#  '₹4,86,599',
#  '₹8,75,000',
#  '₹5,16,999',
#  '₹2,24,299',
#  '₹4,02,199',
#  '₹5,71,399',
#  '₹5,12,899',
#  '₹4,23,499',
#  '₹2,93,599',
#  '₹1,58,499',
#  '₹3,78,699',
#  '₹7,94,699',
#  '₹5,12,799',
#  '₹3,96,599',
#  '₹6,60,099',
#  '₹4,12,199',
#  '₹3,76,999',
#  '₹4,88,599',
#  '₹2,41,399',
#  '₹2,35,099',
#  '₹2,77,000',
#  '₹3,76,999',
#  '₹3,52,000',
#  '₹3,52,599',
#  '₹6,15,000',
#  '₹2,98,099',
#  '₹4,90,999',
#  '₹2,21,999',
#  '₹1,90,199',
#  '₹3,63,099',
#  '₹1,77,399',
#  '₹2,35,899',
#  '₹4,75,099',
#  '₹3,50,899',
#  '₹3,57,099',
#  '₹2,29,799',
#  '₹3,51,599',
#  '₹2,68,599',
#  '₹3,99,499',
#  '₹3,98,899',
#  '₹3,48,599',
#  '₹5,09,599',
#  '₹4,32,699',
#  '₹3,08,199',
#  '₹2,86,399',
#  '₹3,02,599',
#  '₹2,89,299',
#  '₹1,74,699',
#  '₹3,24,099',
#  '₹4,14,199',
#  '₹2,71,299',
#  '₹6,30,399',
#  '₹4,18,599',
#  '₹3,59,499',
#  '₹3,22,699',
#  '₹3,51,899',
#  '₹3,03,000',
#  '₹4,54,899',
#  '₹2,06,699',
#  '₹2,67,000',
# ...

# %%
fuel_type=[]
try:
    type=driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[3]')
    for i in type:
        fuel_type.append(i.text)
except NoSuchElementException:
    fuel_type.append('-')
fuel_type
# Out:
# ['Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol + CNG',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
# ...

# %%
kilometers=[]
try:
    kms=driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[1]')
    for i in kms:
        kilometers.append(i.text)
except NoSuchElementException:
    kilometers.append('-')
kilometers
# Out:
# ['2,079 km',
#  '3,920 km',
#  '2,206 km',
#  '3,459 km',
#  '1,878 km',
#  '8,967 km',
#  '3,176 km',
#  '4,955 km',
#  '7,242 km',
#  '6,100 km',
#  '12,535 km',
#  '34,611 km',
#  '17,839 km',
#  '2,589 km',
#  '7,587 km',
#  '24,022 km',
#  '12,519 km',
#  '4,093 km',
#  '43,114 km',
#  '9,860 km',
#  '35,726 km',
#  '33,437 km',
#  '9,975 km',
#  '22,836 km',
#  '15,509 km',
#  '11,691 km',
#  '8,526 km',
#  '22,176 km',
#  '30,804 km',
#  '24,353 km',
#  '61,129 km',
#  '26,908 km',
#  '39,300 km',
#  '26,525 km',
#  '26,243 km',
#  '5,062 km',
#  '7,610 km',
#  '33,175 km',
#  '16,451 km',
#  '23,227 km',
#  '21,843 km',
#  '3,403 km',
#  '12,139 km',
#  '21,634 km',
#  '9,987 km',
#  '10,608 km',
#  '17,637 km',
#  '18,797 km',
#  '20,231 km',
#  '29,645 km',
#  '7,093 km',
#  '37,263 km',
#  '42,961 km',
#  '14,718 km',
#  '12,808 km',
#  '2,723 km',
#  '2,147 km',
#  '28,704 km',
#  '13,289 km',
#  '13,899 km',
#  '25,610 km',
#  '20,494 km',
#  '25,254 km',
# ...

# %%
owners=[]
try:
    no=driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[2]')
    for i in no:
        owners.append(i.text)
except NoSuchElementException:
    owners.append('-')
owners
# Out:
# ['1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '3rd Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
# ...

# %%
len(model),len(fuel_type),len(kilometers),len(owners),len(Price)
# Out:
# (2460, 2460, 2460, 2460, 2460)

# %%
# creating a pandas dataframe
data12= pd.DataFrame({'website':'Cars24','model':model,'fuel-type':fuel_type,'location':'Delhi','driven kilometers':kilometers,'No of owners':owners,'Price':Price})
  # show the dataframe
data12
# Out:
#      website                    model fuel-type location driven kilometers  \
# 0     Cars24      2021 Nissan MAGNITE    Petrol    Delhi          2,079 km
# 1     Cars24       2020 Maruti Baleno    Petrol    Delhi          3,920 km
# 2     Cars24        2020 Maruti IGNIS    Petrol    Delhi          2,206 km
# 3     Cars24     2021 HYUNDAI NEW I20    Petrol    Delhi          3,459 km
# 4     Cars24        2020 Maruti IGNIS    Petrol    Delhi          1,878 km
# ...      ...                      ...       ...      ...               ...
# 2455  Cars24       2019 Maruti Baleno    Petrol    Delhi         22,999 km
# 2456  Cars24  2019 Hyundai NEW SANTRO    Petrol    Delhi          8,632 km
# 2457  Cars24       2018 Maruti Baleno    Petrol    Delhi         31,514 km
# 2458  Cars24          2019 Tata Tiago    Petrol    Delhi         32,535 km
# 2459  Cars24   2014 Hyundai Elite i20    Diesel    Delhi         72,907 km
#
#      No of owners      Price
# 0       1st Owner  ₹8,05,000
# ...

# %% [markdown]
# ### Noida

# %%
#getting the url
url = "https://www.cars24.com/buy-used-car?sort=P&storeCityId=134&pinId=201301"
driver.get(url)
time.sleep(2)

# %%
car_urls = []
url=driver.find_elements_by_xpath('//a[@class="_9Ue0B"]')       
for i in url:
    car_urls.append(i.get_attribute("href"))                       
car_urls
# Out:
# ['https://www.cars24.com/buy-used-Nissan-MAGNITE-2021-cars-New-Delhi-1001685303/',
#  'https://www.cars24.com/buy-used-Maruti-Baleno-2020-cars-New-Delhi-2336817942/',
#  'https://www.cars24.com/buy-used-Maruti-IGNIS-2020-cars-Faridabad-1104943044/',
#  'https://www.cars24.com/buy-used-HYUNDAI-NEW-I20-2021-cars-New-Delhi-1006723403/',
#  'https://www.cars24.com/buy-used-Maruti-IGNIS-2020-cars-New-Delhi-1125187206/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-800-2013-cars-New-Delhi-1055227042/',
#  'https://www.cars24.com/buy-used-Maruti-S-PRESSO-2020-cars-New-Delhi-1108486124/',
#  'https://www.cars24.com/buy-used-Hyundai-GRAND-I10-NIOS-2020-cars-Noida-1488790147/',
#  'https://www.cars24.com/buy-used-Maruti-New--Wagon-R-2020-cars-New-Delhi-1001646140/',
#  'https://www.cars24.com/buy-used-Maruti-S-PRESSO-2020-cars-New-Delhi-1003019901/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-800-2014-cars-New-Delhi-1057739946/',
# ...

# %%
model=[]
try:
    brand=driver.find_elements_by_xpath('//h2[@class="_3FpCg"]')
    for i in brand:
        model.append(i.text)
except NoSuchElementException:
    model.append('-')
model
# Out:
# ['2021 Nissan MAGNITE',
#  '2020 Maruti Baleno',
#  '2020 Maruti IGNIS',
#  '2021 HYUNDAI NEW I20',
#  '2020 Maruti IGNIS',
#  '2013 Maruti Alto 800',
#  '2020 Maruti S PRESSO',
#  '2020 Hyundai GRAND I10 NIOS',
#  '2020 Maruti New Wagon-R',
#  '2020 Maruti S PRESSO',
#  '2014 Maruti Alto 800',
#  '2010 Maruti Alto',
#  '2016 Maruti Celerio',
#  '2021 Hyundai VENUE',
#  '2019 Renault TRIBER',
#  '2013 Maruti Swift',
#  '2020 Maruti Baleno',
#  '2016 Maruti Celerio',
#  '2011 Toyota Corolla Altis',
#  '2019 Maruti Celerio',
#  '2013 Hyundai Santro Xing',
#  '2014 Hyundai Santro Xing',
#  '2015 Hyundai Eon',
#  '2014 Hyundai Grand i10',
#  '2014 Honda Brio',
#  '2017 Maruti Alto K10',
#  '2020 Tata Tiago',
#  '2015 Hyundai Eon',
#  '2015 Maruti Baleno',
#  '2011 Maruti Alto K10',
#  '2011 Volkswagen Polo',
#  '2013 Maruti Swift',
#  '2011 Maruti Zen Estilo',
#  '2015 Maruti Alto 800',
#  '2017 Hyundai Grand i10',
#  '2019 Renault Kwid',
#  '2020 Maruti Alto',
# ...

# %%
Price=[]
try:
    price=driver.find_elements_by_xpath('//div[@class="_7udZZ"]/span')
    for i in price:
        Price.append(i.text)
except NoSuchElementException:
    Price.append('-')
Price
# Out:
# ['₹8,05,000',
#  '₹6,45,199',
#  '₹4,86,599',
#  '₹8,75,000',
#  '₹5,16,999',
#  '₹2,24,299',
#  '₹4,02,199',
#  '₹5,71,399',
#  '₹5,12,899',
#  '₹4,23,499',
#  '₹2,93,599',
#  '₹1,58,499',
#  '₹3,78,699',
#  '₹7,94,699',
#  '₹5,12,799',
#  '₹3,96,599',
#  '₹6,60,099',
#  '₹4,12,199',
#  '₹3,76,999',
#  '₹4,88,599',
#  '₹2,41,399',
#  '₹2,35,099',
#  '₹2,77,000',
#  '₹3,76,999',
#  '₹3,52,000',
#  '₹3,52,599',
#  '₹6,15,000',
#  '₹2,98,099',
#  '₹4,90,999',
#  '₹2,21,999',
#  '₹1,90,199',
#  '₹3,63,099',
#  '₹1,77,399',
#  '₹2,35,899',
#  '₹4,75,099',
#  '₹3,50,899',
#  '₹3,57,099',
#  '₹2,29,799',
#  '₹3,51,599',
#  '₹2,68,599',
#  '₹3,99,499',
#  '₹3,98,899',
#  '₹3,48,599',
#  '₹5,09,599',
#  '₹4,32,699',
#  '₹3,08,199',
#  '₹2,86,399',
#  '₹3,02,599',
#  '₹2,89,299',
#  '₹1,74,699',
#  '₹3,24,099',
#  '₹4,14,199',
#  '₹2,71,299',
#  '₹6,30,399',
#  '₹4,18,599',
#  '₹3,59,499',
#  '₹3,22,699',
#  '₹3,51,899',
#  '₹3,03,000',
#  '₹4,54,899',
#  '₹2,06,699',
#  '₹2,67,000',
# ...

# %%
fuel_type=[]
try:
    type=driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[3]')
    for i in type:
        fuel_type.append(i.text)
except NoSuchElementException:
    fuel_type.append('-')
fuel_type
# Out:
# ['Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol + CNG',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
# ...

# %%
kilometers=[]
try:
    kms=driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[1]')
    for i in kms:
        kilometers.append(i.text)
except NoSuchElementException:
    kilometers.append('-')
kilometers
# Out:
# ['2,079 km',
#  '3,920 km',
#  '2,206 km',
#  '3,459 km',
#  '1,878 km',
#  '8,967 km',
#  '3,176 km',
#  '4,955 km',
#  '7,242 km',
#  '6,100 km',
#  '12,535 km',
#  '34,611 km',
#  '17,839 km',
#  '2,589 km',
#  '7,587 km',
#  '24,022 km',
#  '12,519 km',
#  '4,093 km',
#  '43,114 km',
#  '9,860 km',
#  '35,726 km',
#  '33,437 km',
#  '9,975 km',
#  '22,836 km',
#  '15,509 km',
#  '11,691 km',
#  '8,526 km',
#  '22,176 km',
#  '30,804 km',
#  '24,353 km',
#  '61,129 km',
#  '26,908 km',
#  '39,300 km',
#  '26,525 km',
#  '26,243 km',
#  '5,062 km',
#  '7,610 km',
#  '33,175 km',
#  '16,451 km',
#  '23,227 km',
#  '21,843 km',
#  '3,403 km',
#  '12,139 km',
#  '21,634 km',
#  '9,987 km',
#  '10,608 km',
#  '17,637 km',
#  '18,797 km',
#  '20,231 km',
#  '29,645 km',
#  '7,093 km',
#  '37,263 km',
#  '42,961 km',
#  '14,718 km',
#  '12,808 km',
#  '2,723 km',
#  '2,147 km',
#  '28,704 km',
#  '13,289 km',
#  '13,899 km',
#  '25,610 km',
#  '20,494 km',
#  '25,254 km',
# ...

# %%
owners=[]
try:
    no=driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[2]')
    for i in no:
        owners.append(i.text)
except NoSuchElementException:
    owners.append('-')
owners
# Out:
# ['1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '3rd Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
# ...

# %%
# creating a pandas dataframe
data13= pd.DataFrame({'website':'Cars24','model':model,'fuel-type':fuel_type,'location':'Noida','driven kilometers':kilometers,'No of owners':owners,'Price':Price})
  # show the dataframe
data13
# Out:
#      website                   model fuel-type location driven kilometers  \
# 0     Cars24     2021 Nissan MAGNITE    Petrol    Noida          2,079 km
# 1     Cars24      2020 Maruti Baleno    Petrol    Noida          3,920 km
# 2     Cars24       2020 Maruti IGNIS    Petrol    Noida          2,206 km
# 3     Cars24    2021 HYUNDAI NEW I20    Petrol    Noida          3,459 km
# 4     Cars24       2020 Maruti IGNIS    Petrol    Noida          1,878 km
# ...      ...                     ...       ...      ...               ...
# 1175  Cars24        2018 Honda Amaze    Diesel    Noida         56,926 km
# 1176  Cars24      2014 Hyundai Verna    Diesel    Noida         84,334 km
# 1177  Cars24      2013 Toyota Innova    Diesel    Noida         88,190 km
# 1178  Cars24  2013 Toyota Etios Liva    Diesel    Noida         97,735 km
# 1179  Cars24        2009 Honda Civic    Petrol    Noida         98,076 km
#
#      No of owners      Price
# 0       1st Owner  ₹8,05,000
# ...

# %%
#getting the url
url = "https://www.cars24.com/buy-used-car?sort=P&storeCityId=5&pinId=122001"
driver.get(url)
time.sleep(2)

# %%
car_urls = []
url=driver.find_elements_by_xpath('//a[@class="_9Ue0B"]')       
for i in url:
    car_urls.append(i.get_attribute("href"))                       
car_urls
# Out:
# ['https://www.cars24.com/buy-used-Nissan-MAGNITE-2021-cars-New-Delhi-1001685303/',
#  'https://www.cars24.com/buy-used-Maruti-Baleno-2020-cars-New-Delhi-2336817942/',
#  'https://www.cars24.com/buy-used-Maruti-IGNIS-2020-cars-Faridabad-1104943044/',
#  'https://www.cars24.com/buy-used-HYUNDAI-NEW-I20-2021-cars-New-Delhi-1006723403/',
#  'https://www.cars24.com/buy-used-Maruti-IGNIS-2020-cars-New-Delhi-1125187206/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-800-2013-cars-New-Delhi-1055227042/',
#  'https://www.cars24.com/buy-used-Maruti-S-PRESSO-2020-cars-New-Delhi-1108486124/',
#  'https://www.cars24.com/buy-used-Hyundai-GRAND-I10-NIOS-2020-cars-Noida-1488790147/',
#  'https://www.cars24.com/buy-used-Maruti-New--Wagon-R-2020-cars-New-Delhi-1001646140/',
#  'https://www.cars24.com/buy-used-Maruti-S-PRESSO-2020-cars-New-Delhi-1003019901/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-800-2014-cars-New-Delhi-1057739946/',
# ...

# %%
model=[]
try:
    brand=driver.find_elements_by_xpath('//h2[@class="_3FpCg"]')
    for i in brand:
        model.append(i.text)
except NoSuchElementException:
    model.append('-')
model
# Out:
# ['2021 Nissan MAGNITE',
#  '2020 Maruti Baleno',
#  '2020 Maruti IGNIS',
#  '2021 HYUNDAI NEW I20',
#  '2020 Maruti IGNIS',
#  '2013 Maruti Alto 800',
#  '2020 Maruti S PRESSO',
#  '2020 Hyundai GRAND I10 NIOS',
#  '2020 Maruti New Wagon-R',
#  '2020 Maruti S PRESSO',
#  '2014 Maruti Alto 800',
#  '2010 Maruti Alto',
#  '2016 Maruti Celerio',
#  '2021 Hyundai VENUE',
#  '2019 Renault TRIBER',
#  '2013 Maruti Swift',
#  '2020 Maruti Baleno',
#  '2016 Maruti Celerio',
#  '2011 Toyota Corolla Altis',
#  '2019 Maruti Celerio',
#  '2013 Hyundai Santro Xing',
#  '2014 Hyundai Santro Xing',
#  '2015 Hyundai Eon',
#  '2014 Hyundai Grand i10',
#  '2014 Honda Brio',
#  '2017 Maruti Alto K10',
#  '2020 Tata Tiago',
#  '2015 Hyundai Eon',
#  '2015 Maruti Baleno',
#  '2011 Maruti Alto K10',
#  '2011 Volkswagen Polo',
#  '2013 Maruti Swift',
#  '2011 Maruti Zen Estilo',
#  '2015 Maruti Alto 800',
#  '2017 Hyundai Grand i10',
#  '2019 Renault Kwid',
#  '2020 Maruti Alto',
# ...

# %%
Price=[]
try:
    price=driver.find_elements_by_xpath('//div[@class="_7udZZ"]/span')
    for i in price:
        Price.append(i.text)
except NoSuchElementException:
    Price.append('-')
Price
# Out:
# ['₹8,05,000',
#  '₹6,45,199',
#  '₹4,86,599',
#  '₹8,75,000',
#  '₹5,16,999',
#  '₹2,24,299',
#  '₹4,02,199',
#  '₹5,71,399',
#  '₹5,12,899',
#  '₹4,23,499',
#  '₹2,93,599',
#  '₹1,58,499',
#  '₹3,78,699',
#  '₹7,94,699',
#  '₹5,12,799',
#  '₹3,96,599',
#  '₹6,60,099',
#  '₹4,12,199',
#  '₹3,76,999',
#  '₹4,88,599',
#  '₹2,41,399',
#  '₹2,35,099',
#  '₹2,77,000',
#  '₹3,76,999',
#  '₹3,52,000',
#  '₹3,52,599',
#  '₹6,15,000',
#  '₹2,98,099',
#  '₹4,90,999',
#  '₹2,21,999',
#  '₹1,90,199',
#  '₹3,63,099',
#  '₹1,77,399',
#  '₹2,35,899',
#  '₹4,75,099',
#  '₹3,50,899',
#  '₹3,57,099',
#  '₹2,29,799',
#  '₹3,51,599',
#  '₹2,68,599',
#  '₹3,98,899',
#  '₹3,48,599',
#  '₹5,09,599',
#  '₹4,32,699',
#  '₹3,08,199',
#  '₹2,86,399',
#  '₹3,02,599',
#  '₹2,89,299',
#  '₹1,74,699',
#  '₹3,24,099',
#  '₹4,14,199',
#  '₹2,71,299',
#  '₹6,30,399',
#  '₹4,18,599',
#  '₹3,59,499',
#  '₹3,22,699',
#  '₹3,51,899',
#  '₹3,03,000',
#  '₹4,54,899',
#  '₹2,06,699',
#  '₹2,67,000',
#  '₹5,95,099',
# ...

# %%
fuel_type=[]
try:
    type=driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[3]')
    for i in type:
        fuel_type.append(i.text)
except NoSuchElementException:
    fuel_type.append('-')
fuel_type
# Out:
# ['Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol + CNG',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
# ...

# %%
kilometers=[]
try:
    kms=driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[1]')
    for i in kms:
        kilometers.append(i.text)
except NoSuchElementException:
    kilometers.append('-')
kilometers
# Out:
# ['2,079 km',
#  '3,920 km',
#  '2,206 km',
#  '3,459 km',
#  '1,878 km',
#  '8,967 km',
#  '3,176 km',
#  '4,955 km',
#  '7,242 km',
#  '6,100 km',
#  '12,535 km',
#  '34,611 km',
#  '17,839 km',
#  '2,589 km',
#  '7,587 km',
#  '24,022 km',
#  '12,519 km',
#  '4,093 km',
#  '43,114 km',
#  '9,860 km',
#  '35,726 km',
#  '33,437 km',
#  '9,975 km',
#  '22,836 km',
#  '15,509 km',
#  '11,691 km',
#  '8,526 km',
#  '22,176 km',
#  '30,804 km',
#  '24,353 km',
#  '61,129 km',
#  '26,908 km',
#  '39,300 km',
#  '26,525 km',
#  '26,243 km',
#  '5,062 km',
#  '7,610 km',
#  '33,175 km',
#  '16,451 km',
#  '23,227 km',
#  '3,403 km',
#  '12,139 km',
#  '21,634 km',
#  '9,987 km',
#  '10,608 km',
#  '17,637 km',
#  '18,797 km',
#  '20,231 km',
#  '29,645 km',
#  '7,093 km',
#  '37,263 km',
#  '42,961 km',
#  '14,718 km',
#  '12,808 km',
#  '2,723 km',
#  '2,147 km',
#  '28,704 km',
#  '13,289 km',
#  '13,899 km',
#  '25,610 km',
#  '20,494 km',
#  '25,254 km',
#  '49,654 km',
# ...

# %%
owners=[]
try:
    no=driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[2]')
    for i in no:
        owners.append(i.text)
except NoSuchElementException:
    owners.append('-')
owners
# Out:
# ['1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '3rd Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
# ...

# %%
len(model),len(fuel_type),len(kilometers),len(owners),len(Price)
# Out:
# (580, 580, 580, 580, 580)

# %%
# creating a pandas dataframe
data13= pd.DataFrame({'website':'Cars24','model':model,'fuel-type':fuel_type,'location':'Gurgaon','driven kilometers':kilometers,'No of owners':owners,'Price':Price})
  # show the dataframe
data13
# Out:
#     website                    model fuel-type location driven kilometers  \
# 0    Cars24      2021 Nissan MAGNITE    Petrol  Gurgaon          2,079 km
# 1    Cars24       2020 Maruti Baleno    Petrol  Gurgaon          3,920 km
# 2    Cars24        2020 Maruti IGNIS    Petrol  Gurgaon          2,206 km
# 3    Cars24     2021 HYUNDAI NEW I20    Petrol  Gurgaon          3,459 km
# 4    Cars24        2020 Maruti IGNIS    Petrol  Gurgaon          1,878 km
# ..      ...                      ...       ...      ...               ...
# 575  Cars24      2016 Datsun Redi Go    Petrol  Gurgaon         40,820 km
# 576  Cars24       2018 Maruti Baleno    Petrol  Gurgaon         33,770 km
# 577  Cars24        2018 Maruti Dzire    Petrol  Gurgaon         43,499 km
# 578  Cars24   2015 Hyundai Elite i20    Diesel  Gurgaon         76,443 km
# 579  Cars24  2013 Maruti Swift Dzire    Petrol  Gurgaon         60,460 km
#
#     No of owners      Price
# 0      1st Owner  ₹8,05,000
# ...

# %% [markdown]
# ### Mumbai

# %%
#getting the url
url = "https://www.cars24.com/buy-used-car?sort=P&storeCityId=2378&pinId=400001"
driver.get(url)
time.sleep(2)

# %%
car_urls = []
url=driver.find_elements_by_xpath('//a[@class="_9Ue0B"]')       
for i in url:
    car_urls.append(i.get_attribute("href"))                       
car_urls
# Out:
# ['https://www.cars24.com/buy-used-Honda-Brio-2012-cars-Mumbai-1034876820/',
#  'https://www.cars24.com/buy-used-Maruti-Wagon-R-1.0-2013-cars-Mumbai-1035614922/',
#  'https://www.cars24.com/buy-used-Maruti-Wagon-R-1.0-2014-cars-Mumbai-1034019348/',
#  'https://www.cars24.com/buy-used-Maruti-New--Wagon-R-2020-cars-Mumbai-1039966825/',
#  'https://www.cars24.com/buy-used-Maruti-Swift-2020-cars-Mumbai-1030234244/',
#  'https://www.cars24.com/buy-used-Maruti-Wagon-R-1.0-2015-cars-Mumbai-1034121847/',
#  'https://www.cars24.com/buy-used-Maruti-A-Star-2011-cars-Mumbai-1033369145/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-K10-2017-cars-Mumbai-1037345342/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-800-2018-cars-Mumbai-1037574729/',
#  'https://www.cars24.com/buy-used-Maruti-Wagon-R-1.0-2013-cars-Mumbai-1030821026/',
#  'https://www.cars24.com/buy-used-Maruti-Swift-2017-cars-Mumbai-1032126945/',
# ...

# %%
model=[]
try:
    brand=driver.find_elements_by_xpath('//h2[@class="_3FpCg"]')
    for i in brand:
        model.append(i.text)
except NoSuchElementException:
    model.append('-')
model
# Out:
# ['2012 Honda Brio',
#  '2013 Maruti Wagon R 1.0',
#  '2014 Maruti Wagon R 1.0',
#  '2020 Maruti New Wagon-R',
#  '2020 Maruti Swift',
#  '2015 Maruti Wagon R 1.0',
#  '2011 Maruti A Star',
#  '2017 Maruti Alto K10',
#  '2018 Maruti Alto 800',
#  '2013 Maruti Wagon R 1.0',
#  '2017 Maruti Swift',
#  '2015 Hyundai Grand i10',
#  '2018 Hyundai NEW SANTRO',
#  '2014 Hyundai Xcent',
#  '2012 Maruti Wagon R 1.0',
#  '2010 Hyundai i20',
#  '2015 Maruti Swift Dzire',
#  '2014 Maruti Swift',
#  '2016 Maruti Alto K10',
#  '2014 Maruti Wagon R 1.0',
#  '2015 Hyundai Elite i20',
#  '2014 Hyundai Xcent',
#  '2011 Maruti Alto',
#  '2016 Maruti Alto K10',
#  '2019 Hyundai NEW SANTRO',
#  '2017 Maruti Alto 800',
#  '2016 Tata Zest',
#  '2017 Maruti IGNIS',
#  '2015 Maruti Swift',
#  '2014 Hyundai Grand i10',
#  '2017 Hyundai Elite i20',
#  '2015 Maruti Alto 800',
#  '2013 Maruti Alto 800',
#  '2015 Maruti Swift Dzire',
#  '2013 Maruti Wagon R 1.0',
#  '2015 Maruti Wagon R 1.0',
# ...

# %%
Price=[]
try:
    price=driver.find_elements_by_xpath('//div[@class="_7udZZ"]/span')
    for i in price:
        Price.append(i.text)
except NoSuchElementException:
    Price.append('-')
Price
# Out:
# ['₹2,81,199',
#  '₹2,99,399',
#  '₹3,42,499',
#  '₹5,58,199',
#  '₹6,29,399',
#  '₹3,51,499',
#  '₹1,74,899',
#  '₹3,47,999',
#  '₹3,40,999',
#  '₹2,70,499',
#  '₹5,13,999',
#  '₹3,78,399',
#  '₹5,28,699',
#  '₹4,75,499',
#  '₹2,52,099',
#  '₹3,11,099',
#  '₹4,86,199',
#  '₹3,77,299',
#  '₹3,24,799',
#  '₹3,40,699',
#  '₹5,92,999',
#  '₹3,99,099',
#  '₹1,60,000',
#  '₹2,94,299',
#  '₹4,62,499',
#  '₹3,00,699',
#  '₹3,89,799',
#  '₹5,70,299',
#  '₹3,91,199',
#  '₹3,85,399',
#  '₹6,15,599',
#  '₹2,43,899',
#  '₹2,11,199',
#  '₹4,51,699',
#  '₹2,95,399',
#  '₹3,19,799',
#  '₹4,68,999',
#  '₹3,07,299',
#  '₹4,75,199',
#  '₹2,89,299',
#  '₹2,19,299',
#  '₹3,86,799',
#  '₹3,45,399',
#  '₹3,88,499',
#  '₹3,43,399',
#  '₹2,32,999',
#  '₹2,77,599',
#  '₹2,93,099',
#  '₹3,86,399',
#  '₹4,88,599',
#  '₹4,41,799',
#  '₹3,96,599',
#  '₹3,47,799',
#  '₹2,15,099',
#  '₹1,67,299',
#  '₹4,45,899',
#  '₹4,72,599',
#  '₹2,61,899',
#  '₹5,99,399',
#  '₹3,92,599',
#  '₹2,95,399',
#  '₹4,29,299',
# ...

# %%
fuel_type=[]
try:
    type=driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[3]')
    for i in type:
        fuel_type.append(i.text)
except NoSuchElementException:
    fuel_type.append('-')
fuel_type
# Out:
# ['Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
# ...

# %%
owners=[]
try:
    no=driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[2]')
    for i in no:
        owners.append(i.text)
except NoSuchElementException:
    owners.append('-')
owners
# Out:
# ['3rd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '3rd Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
# ...

# %%
kilometers=[]
try:
    kms=driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[1]')
    for i in kms:
        kilometers.append(i.text)
except NoSuchElementException:
    kilometers.append('-')
kilometers
# Out:
# ['13,567 km',
#  '13,688 km',
#  '11,365 km',
#  '17,310 km',
#  '5,851 km',
#  '13,522 km',
#  '29,603 km',
#  '5,562 km',
#  '4,343 km',
#  '15,738 km',
#  '5,906 km',
#  '16,048 km',
#  '4,972 km',
#  '7,999 km',
#  '20,712 km',
#  '13,276 km',
#  '15,052 km',
#  '22,424 km',
#  '13,851 km',
#  '20,071 km',
#  '5,694 km',
#  '27,075 km',
#  '15,537 km',
#  '15,395 km',
#  '9,521 km',
#  '9,899 km',
#  '11,414 km',
#  '5,328 km',
#  '26,514 km',
#  '25,150 km',
#  '4,249 km',
#  '30,242 km',
#  '26,848 km',
#  '23,070 km',
#  '24,065 km',
#  '30,131 km',
#  '8,484 km',
#  '28,817 km',
#  '16,617 km',
#  '5,461 km',
#  '32,101 km',
#  '19,428 km',
#  '25,928 km',
#  '28,543 km',
#  '20,416 km',
#  '27,179 km',
#  '19,467 km',
#  '37,291 km',
#  '30,736 km',
#  '18,043 km',
#  '35,527 km',
#  '30,761 km',
#  '37,455 km',
#  '43,411 km',
#  '37,168 km',
#  '21,485 km',
#  '33,644 km',
#  '24,171 km',
#  '8,000 km',
#  '35,311 km',
#  '26,374 km',
#  '21,129 km',
#  '16,498 km',
# ...

# %%
# creating a pandas dataframe
data14= pd.DataFrame({'website':'Cars24','model':model,'fuel-type':fuel_type,'location':'Mumbai','driven kilometers':kilometers,'No of owners':owners,'Price':Price})
  # show the dataframe
data14
# Out:
#      website                    model fuel-type location driven kilometers  \
# 0     Cars24          2012 Honda Brio    Petrol   Mumbai         13,567 km
# 1     Cars24  2013 Maruti Wagon R 1.0    Petrol   Mumbai         13,688 km
# 2     Cars24  2014 Maruti Wagon R 1.0    Petrol   Mumbai         11,365 km
# 3     Cars24  2020 Maruti New Wagon-R    Petrol   Mumbai         17,310 km
# 4     Cars24        2020 Maruti Swift    Petrol   Mumbai          5,851 km
# ...      ...                      ...       ...      ...               ...
# 2170  Cars24       2010 Toyota Innova    Diesel   Mumbai       1,72,520 km
# 2171  Cars24         2014 Maruti Ciaz    Diesel   Mumbai       1,00,831 km
# 2172  Cars24        2012 Maruti Swift    Diesel   Mumbai       1,70,591 km
# 2173  Cars24          2018 Tata Tiago    Petrol   Mumbai         49,670 km
# 2174  Cars24          2014 Honda City    Diesel   Mumbai       1,09,695 km
#
#      No of owners      Price
# 0       3rd Owner  ₹2,81,199
# ...

# %% [markdown]
# ### Pune

# %%
#getting the url
url = "https://www.cars24.com/buy-used-car?sort=P&storeCityId=2423&pinId=411001"
driver.get(url)
time.sleep(2)

# %%
car_urls = []
url=driver.find_elements_by_xpath('//a[@class="_9Ue0B"]')       
for i in url:
    car_urls.append(i.get_attribute("href"))                       
car_urls
# Out:
# ['https://www.cars24.com/buy-used-Maruti-Alto-800-2015-cars-Pune-1063514322/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-K10-2015-cars-Pune-1066948547/',
#  'https://www.cars24.com/buy-used-Maruti-Wagon-R-1.0-2012-cars-Pune-1031616524/',
#  'https://www.cars24.com/buy-used-Maruti-Wagon-R-1.0-2013-cars-Pune-1033272720/',
#  'https://www.cars24.com/buy-used-Maruti-Wagon-R-1.0-2016-cars-Pune-1037733941/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-2011-cars-Pune-1067034940/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-K10-2015-cars-Pune-1031970121/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-K10-2015-cars-Pune-1065912847/',
#  'https://www.cars24.com/buy-used-Hyundai-i10-2016-cars-Pune-1031542028/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-800-2015-cars-Pune-1061081046/',
#  'https://www.cars24.com/buy-used-Renault-TRIBER-2019-cars-Pune-1060108141/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-800-2018-cars-Pune-1069955444/',
# ...

# %%
model=[]
try:
    brand=driver.find_elements_by_xpath('//h2[@class="_3FpCg"]')
    for i in brand:
        model.append(i.text)
except NoSuchElementException:
    model.append('-')
model
# Out:
# ['2015 Maruti Alto 800',
#  '2015 Maruti Alto K10',
#  '2012 Maruti Wagon R 1.0',
#  '2013 Maruti Wagon R 1.0',
#  '2016 Maruti Wagon R 1.0',
#  '2011 Maruti Alto',
#  '2015 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2016 Hyundai i10',
#  '2015 Maruti Alto 800',
#  '2019 Renault TRIBER',
#  '2018 Maruti Alto 800',
#  '2019 Maruti Celerio',
#  '2018 Hyundai NEW SANTRO',
#  '2020 Maruti S PRESSO',
#  '2017 Maruti Swift',
#  '2014 Hyundai Xcent',
#  '2016 Renault Kwid',
#  '2016 Maruti Alto 800',
#  '2010 Maruti A Star',
#  '2017 Maruti Wagon R 1.0',
#  '2014 Maruti Alto 800',
#  '2016 Maruti Alto K10',
#  '2017 Maruti Alto 800',
#  '2014 Maruti Alto 800',
#  '2014 Maruti Alto 800',
#  '2014 Hyundai Elite i20',
#  '2014 Honda Amaze',
#  '2015 Hyundai Grand i10',
#  '2011 Volkswagen Polo',
#  '2014 Maruti Alto K10',
#  '2014 Honda Amaze',
#  '2016 Maruti Alto 800',
#  '2017 Maruti Alto 800',
#  '2015 Hyundai Grand i10',
#  '2015 Maruti Wagon R 1.0',
#  '2016 Hyundai Elite i20',
# ...

# %%
Price=[]
try:
    price=driver.find_elements_by_xpath('//div[@class="_7udZZ"]/span')
    for i in price:
        Price.append(i.text)
except NoSuchElementException:
    Price.append('-')
Price
# Out:
# ['₹2,56,099',
#  '₹3,34,699',
#  '₹2,60,999',
#  '₹3,02,699',
#  '₹3,87,999',
#  '₹1,82,699',
#  '₹2,55,799',
#  '₹3,22,599',
#  '₹3,46,499',
#  '₹2,77,599',
#  '₹5,98,299',
#  '₹3,41,499',
#  '₹5,14,999',
#  '₹5,00,499',
#  '₹4,53,699',
#  '₹5,02,699',
#  '₹4,01,299',
#  '₹2,76,999',
#  '₹2,94,799',
#  '₹1,94,899',
#  '₹3,82,799',
#  '₹1,94,699',
#  '₹3,13,499',
#  '₹3,25,099',
#  '₹2,36,799',
#  '₹2,45,199',
#  '₹4,76,299',
#  '₹4,14,599',
#  '₹4,23,899',
#  '₹2,77,899',
#  '₹2,41,499',
#  '₹4,09,099',
#  '₹2,79,399',
#  '₹3,11,499',
#  '₹4,38,099',
#  '₹3,30,999',
#  '₹5,33,699',
#  '₹2,34,599',
#  '₹2,51,399',
#  '₹6,14,399',
#  '₹3,36,599',
#  '₹5,20,599',
#  '₹4,51,899',
#  '₹2,41,099',
#  '₹2,71,099',
#  '₹2,66,199',
#  '₹3,03,799',
#  '₹2,95,399',
#  '₹2,51,699',
#  '₹3,23,699',
#  '₹5,79,099',
#  '₹4,50,399',
#  '₹6,31,599',
#  '₹3,47,399',
#  '₹2,47,899',
#  '₹3,34,599',
#  '₹5,83,899',
#  '₹2,57,499',
#  '₹3,26,099',
#  '₹6,41,599',
#  '₹1,78,499',
#  '₹4,04,299',
# ...

# %%
fuel_type=[]
try:
    type=driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[3]')
    for i in type:
        fuel_type.append(i.text)
except NoSuchElementException:
    fuel_type.append('-')
fuel_type
# Out:
# ['Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol + CNG',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
# ...

# %%
owners=[]
try:
    no=driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[2]')
    for i in no:
        owners.append(i.text)
except NoSuchElementException:
    owners.append('-')
owners
# Out:
# ['2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '1st Owner',
#  '3rd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
# ...

# %%
kilometers=[]
try:
    kms=driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[1]')
    for i in kms:
        kilometers.append(i.text)
except NoSuchElementException:
    kilometers.append('-')
kilometers
# Out:
# ['7,478 km',
#  '9,013 km',
#  '21,852 km',
#  '17,781 km',
#  '9,520 km',
#  '17,340 km',
#  '12,657 km',
#  '12,341 km',
#  '12,479 km',
#  '13,222 km',
#  '2,058 km',
#  '4,065 km',
#  '6,559 km',
#  '6,874 km',
#  '8,651 km',
#  '9,825 km',
#  '19,607 km',
#  '16,887 km',
#  '12,692 km',
#  '25,211 km',
#  '20,577 km',
#  '31,889 km',
#  '25,943 km',
#  '16,069 km',
#  '20,656 km',
#  '22,626 km',
#  '20,914 km',
#  '24,048 km',
#  '27,404 km',
#  '38,579 km',
#  '29,178 km',
#  '35,265 km',
#  '18,780 km',
#  '15,483 km',
#  '31,300 km',
#  '25,054 km',
#  '22,538 km',
#  '41,270 km',
#  '34,408 km',
#  '8,173 km',
#  '28,842 km',
#  '20,910 km',
#  '8,814 km',
#  '10,342 km',
#  '40,497 km',
#  '19,793 km',
#  '36,697 km',
#  '18,419 km',
#  '25,919 km',
#  '17,517 km',
#  '9,214 km',
#  '27,651 km',
#  '7,922 km',
#  '43,680 km',
#  '43,134 km',
#  '20,320 km',
#  '24,756 km',
#  '43,540 km',
#  '38,458 km',
#  '19,612 km',
#  '48,837 km',
#  '23,841 km',
#  '33,475 km',
# ...

# %%
len(model),len(fuel_type),len(kilometers),len(owners),len(Price)
# Out:
# (1607, 1607, 1607, 1607, 1607)

# %%
# creating a pandas dataframe
data15= pd.DataFrame({'website':'Cars24','model':model,'fuel-type':fuel_type,'location':'Pune','driven kilometers':kilometers,'No of owners':owners,'Price':Price})
  # show the dataframe
data15
# Out:
#      website                    model     fuel-type location  \
# 0     Cars24     2015 Maruti Alto 800        Petrol     Pune
# 1     Cars24     2015 Maruti Alto K10        Petrol     Pune
# 2     Cars24  2012 Maruti Wagon R 1.0        Petrol     Pune
# 3     Cars24  2013 Maruti Wagon R 1.0        Petrol     Pune
# 4     Cars24  2016 Maruti Wagon R 1.0        Petrol     Pune
# ...      ...                      ...           ...      ...
# 1602  Cars24              2011 BMW X1        Diesel     Pune
# 1603  Cars24         2011 Hyundai i10        Petrol     Pune
# 1604  Cars24      2009 Maruti Wagon R        Petrol     Pune
# 1605  Cars24       2014 Maruti Ertiga  Petrol + CNG     Pune
# 1606  Cars24       2014 Ford Ecosport        Diesel     Pune
#
#      driven kilometers No of owners      Price
# 0             7,478 km    2nd Owner  ₹2,56,099
# 1             9,013 km    1st Owner  ₹3,34,699
# 2            21,852 km    1st Owner  ₹2,60,999
# ...

# %% [markdown]
# ### Hyderabad

# %%
#getting the url
url = "https://www.cars24.com/buy-used-car?sort=P&storeCityId=3686&pinId=500001"
driver.get(url)
time.sleep(2)

# %%
car_urls = []
url=driver.find_elements_by_xpath('//a[@class="_9Ue0B"]')       
for i in url:
    car_urls.append(i.get_attribute("href"))                       
car_urls
# Out:
# ['https://www.cars24.com/buy-used-Maruti-Wagon-R-1.0-2011-cars-Hyderabad-1046601341/',
#  'https://www.cars24.com/buy-used-Hyundai-i10-2010-cars-Hyderabad-1045849145/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-2011-cars-Hyderabad-1048103624/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-2012-cars-Hyderabad-1045616921/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-800-2018-cars-Hyderabad-1041816520/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-800-2015-cars-Hyderabad-1044417940/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-K10-2012-cars-Hyderabad-1041922328/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-2011-cars-Hyderabad-1043613424/',
#  'https://www.cars24.com/buy-used-Maruti-Eeco-2019-cars-Hyderabad-1047229808/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-2012-cars-Hyderabad-1044177446/',
#  'https://www.cars24.com/buy-used-Maruti-Wagon-R-1.0-2012-cars-Hyderabad-1047002326/',
# ...

# %%
model=[]
try:
    brand=driver.find_elements_by_xpath('//h2[@class="_3FpCg"]')
    for i in brand:
        model.append(i.text)
except NoSuchElementException:
    model.append('-')
model
# Out:
# ['2011 Maruti Wagon R 1.0',
#  '2010 Hyundai i10',
#  '2011 Maruti Alto',
#  '2012 Maruti Alto',
#  '2018 Maruti Alto 800',
#  '2015 Maruti Alto 800',
#  '2012 Maruti Alto K10',
#  '2011 Maruti Alto',
#  '2019 Maruti Eeco',
#  '2012 Maruti Alto',
#  '2012 Maruti Wagon R 1.0',
#  '2012 Maruti Alto K10',
#  '2012 Maruti Ritz',
#  '2019 Maruti Eeco',
#  '2013 Maruti Alto 800',
#  '2018 Maruti Eeco',
#  '2016 Hyundai Eon',
#  '2014 Maruti Wagon R 1.0',
#  '2019 Maruti Eeco',
#  '2012 Hyundai i10',
#  '2018 Maruti Alto 800',
#  '2017 Maruti Alto K10',
#  '2019 Renault Kwid',
#  '2012 Hyundai i10',
#  '2017 Maruti Swift Dzire',
#  '2013 Maruti Wagon R 1.0',
#  '2015 Hyundai Grand i10',
#  '2011 Maruti Wagon R 1.0',
#  '2013 Maruti Alto K10',
#  '2015 Maruti Alto 800',
#  '2011 Maruti Alto',
#  '2010 Hyundai i10',
#  '2011 Maruti Alto K10',
#  '2016 Hyundai Grand i10',
#  '2019 Tata Tiago',
#  '2016 Maruti Baleno',
#  '2010 Maruti Alto',
#  '2019 Maruti Eeco',
#  '2016 Maruti Celerio',
# ...

# %%
Price=[]
try:
    price=driver.find_elements_by_xpath('//div[@class="_7udZZ"]/span')
    for i in price:
        Price.append(i.text)
except NoSuchElementException:
    Price.append('-')
Price
# Out:
# ['₹3,18,299',
#  '₹2,98,299',
#  '₹2,15,199',
#  '₹2,29,799',
#  '₹3,23,799',
#  '₹2,59,099',
#  '₹2,19,199',
#  '₹2,03,299',
#  '₹4,66,399',
#  '₹2,28,899',
#  '₹3,24,899',
#  '₹2,45,999',
#  '₹3,00,199',
#  '₹4,27,899',
#  '₹2,63,199',
#  '₹3,79,399',
#  '₹2,94,899',
#  '₹3,50,799',
#  '₹4,24,699',
#  '₹3,24,199',
#  '₹3,21,099',
#  '₹3,45,899',
#  '₹3,92,099',
#  '₹3,53,099',
#  '₹6,90,499',
#  '₹3,09,599',
#  '₹5,17,599',
#  '₹2,84,599',
#  '₹2,50,699',
#  '₹2,65,999',
#  '₹1,92,999',
#  '₹2,90,099',
#  '₹2,04,299',
#  '₹4,60,299',
#  '₹5,26,999',
#  '₹5,46,099',
#  '₹1,61,199',
#  '₹4,29,399',
#  '₹4,41,699',
#  '₹3,60,399',
#  '₹5,02,999',
#  '₹2,75,099',
#  '₹5,48,699',
#  '₹6,90,799',
#  '₹2,59,399',
#  '₹3,38,699',
#  '₹3,03,599',
#  '₹2,28,399',
#  '₹3,54,199',
#  '₹3,03,199',
#  '₹2,32,099',
#  '₹2,79,199',
#  '₹3,73,599',
#  '₹2,72,999',
#  '₹3,16,199',
#  '₹2,27,699',
#  '₹2,11,499',
#  '₹4,89,799',
#  '₹3,59,899',
#  '₹3,20,699',
#  '₹6,40,499',
#  '₹3,17,999',
# ...

# %%
fuel_type=[]
try:
    type=driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[3]')
    for i in type:
        fuel_type.append(i.text)
except NoSuchElementException:
    fuel_type.append('-')
fuel_type
# Out:
# ['Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
# ...

# %%
owners=[]
try:
    no=driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[2]')
    for i in no:
        owners.append(i.text)
except NoSuchElementException:
    owners.append('-')
owners
# Out:
# ['1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
# ...

# %%
kilometers=[]
try:
    kms=driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[1]')
    for i in kms:
        kilometers.append(i.text)
except NoSuchElementException:
    kilometers.append('-')
kilometers
# Out:
# ['20,979 km',
#  '23,488 km',
#  '23,837 km',
#  '21,215 km',
#  '7,885 km',
#  '29,296 km',
#  '36,870 km',
#  '31,119 km',
#  '9,128 km',
#  '37,800 km',
#  '14,631 km',
#  '28,852 km',
#  '31,891 km',
#  '15,398 km',
#  '31,384 km',
#  '25,514 km',
#  '10,674 km',
#  '15,673 km',
#  '18,951 km',
#  '46,986 km',
#  '18,313 km',
#  '24,809 km',
#  '31,559 km',
#  '49,548 km',
#  '19,208 km',
#  '45,460 km',
#  '35,803 km',
#  '63,165 km',
#  '44,958 km',
#  '47,247 km',
#  '59,373 km',
#  '49,109 km',
#  '47,330 km',
#  '33,396 km',
#  '24,296 km',
#  '33,768 km',
#  '59,344 km',
#  '23,410 km',
#  '34,102 km',
#  '44,514 km',
#  '17,700 km',
#  '33,674 km',
#  '20,577 km',
#  '10,726 km',
#  '61,836 km',
#  '65,288 km',
#  '73,802 km',
#  '64,304 km',
#  '26,234 km',
#  '28,090 km',
#  '44,791 km',
#  '55,317 km',
#  '59,329 km',
#  '46,828 km',
#  '29,700 km',
#  '62,592 km',
#  '40,517 km',
#  '12,750 km',
#  '58,363 km',
#  '30,782 km',
#  '26,796 km',
#  '58,357 km',
# ...

# %%
# creating a pandas dataframe
data16= pd.DataFrame({'website':'Cars24','model':model,'fuel-type':fuel_type,'location':'Hyderabad','driven kilometers':kilometers,'No of owners':owners,'Price':Price})
  # show the dataframe
data16
# Out:
#     website                      model fuel-type   location driven kilometers  \
# 0    Cars24    2011 Maruti Wagon R 1.0    Petrol  Hyderabad         20,979 km
# 1    Cars24           2010 Hyundai i10    Petrol  Hyderabad         23,488 km
# 2    Cars24           2011 Maruti Alto    Petrol  Hyderabad         23,837 km
# 3    Cars24           2012 Maruti Alto    Petrol  Hyderabad         21,215 km
# 4    Cars24       2018 Maruti Alto 800    Petrol  Hyderabad          7,885 km
# ..      ...                        ...       ...        ...               ...
# 313  Cars24         2018 Maruti OMNI E    Petrol  Hyderabad         45,120 km
# 314  Cars24            2018 Tata Tiago    Petrol  Hyderabad         28,399 km
# 315  Cars24    2016 Hyundai i20 Active    Diesel  Hyderabad         57,997 km
# 316  Cars24    2016 Maruti Swift Dzire    Petrol  Hyderabad         69,673 km
# 317  Cars24  2019 Maruti Vitara Brezza    Diesel  Hyderabad         40,871 km
#
#     No of owners      Price
# ...

# %% [markdown]
# ### Chennai

# %%
#getting the url
url = "https://www.cars24.com/buy-used-car?sort=P&storeCityId=5732&pinId=600001"
driver.get(url)
time.sleep(2)

# %%
car_urls = []
url=driver.find_elements_by_xpath('//a[@class="_9Ue0B"]')       
for i in url:
    car_urls.append(i.get_attribute("href"))                       
car_urls
# Out:
# ['https://www.cars24.com/buy-used-Hyundai-i10-2014-cars-Chennai-1130119400/',
#  'https://www.cars24.com/buy-used-Maruti-S-PRESSO-2020-cars-Chennai-1131217203/',
#  'https://www.cars24.com/buy-used-Maruti-Swift-2014-cars-Chennai-1134977246/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-K10-2013-cars-Chennai-1134169444/',
#  'https://www.cars24.com/buy-used-Maruti-Wagon-R-1.0-2011-cars-Chennai-1136387443/',
#  'https://www.cars24.com/buy-used-Maruti-Swift-Dzire-2014-cars-Chennai-1135282921/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-2011-cars-Chennai-1139829240/',
#  'https://www.cars24.com/buy-used-Maruti-Eeco-2020-cars-Chennai-1136477904/',
#  'https://www.cars24.com/buy-used-Maruti-Eeco-2020-cars-Chennai-1138742041/',
#  'https://www.cars24.com/buy-used-Hyundai-i10-2011-cars-Chennai-1137744321/',
#  'https://www.cars24.com/buy-used-Hyundai-NEW-SANTRO-2019-cars-Chennai-1132479447/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-800-2017-cars-Chennai-1130581407/',
# ...

# %%
model=[]
try:
    brand=driver.find_elements_by_xpath('//h2[@class="_3FpCg"]')
    for i in brand:
        model.append(i.text)
except NoSuchElementException:
    model.append('-')
model
# Out:
# ['2014 Hyundai i10',
#  '2020 Maruti S PRESSO',
#  '2014 Maruti Swift',
#  '2013 Maruti Alto K10',
#  '2011 Maruti Wagon R 1.0',
#  '2014 Maruti Swift Dzire',
#  '2011 Maruti Alto',
#  '2020 Maruti Eeco',
#  '2020 Maruti Eeco',
#  '2011 Hyundai i10',
#  '2019 Hyundai NEW SANTRO',
#  '2017 Maruti Alto 800',
#  '2018 Maruti Eeco',
#  '2017 Maruti Eeco',
#  '2017 Maruti Alto 800',
#  '2015 Hyundai Eon',
#  '2014 Maruti Swift Dzire',
#  '2019 Maruti Eeco',
#  '2018 Maruti Alto 800',
#  '2014 Maruti Wagon R 1.0',
#  '2019 Maruti Swift',
#  '2011 Maruti Alto',
#  '2019 Maruti Celerio',
#  '2015 Hyundai Grand i10',
#  '2019 Maruti IGNIS',
#  '2018 Maruti Alto K10',
#  '2014 Maruti Eeco',
#  '2016 Maruti Alto 800',
#  '2015 Maruti Alto K10',
#  '2012 Hyundai i10',
#  '2017 Maruti Eeco',
#  '2017 Hyundai Grand i10',
#  '2015 Maruti Eeco',
#  '2016 Hyundai i10',
#  '2014 Maruti Alto 800',
#  '2018 Maruti Celerio',
#  '2018 Maruti Alto 800',
#  '2018 Maruti Wagon R 1.0',
#  '2016 Honda Jazz',
# ...

# %%
Price=[]
try:
    price=driver.find_elements_by_xpath('//div[@class="_7udZZ"]/span')
    for i in price:
        Price.append(i.text)
except NoSuchElementException:
    Price.append('-')
Price
# Out:
# ['₹3,72,999',
#  '₹4,96,599',
#  '₹4,37,099',
#  '₹2,56,699',
#  '₹2,83,699',
#  '₹4,92,099',
#  '₹2,47,399',
#  '₹4,66,999',
#  '₹4,86,199',
#  '₹3,05,899',
#  '₹5,40,399',
#  '₹3,28,499',
#  '₹4,03,799',
#  '₹4,08,999',
#  '₹3,09,199',
#  '₹2,89,399',
#  '₹4,68,599',
#  '₹4,49,799',
#  '₹3,24,999',
#  '₹3,49,799',
#  '₹5,86,699',
#  '₹2,41,399',
#  '₹4,89,199',
#  '₹4,18,799',
#  '₹5,76,299',
#  '₹3,83,499',
#  '₹3,40,199',
#  '₹2,85,499',
#  '₹3,17,999',
#  '₹3,03,399',
#  '₹3,81,899',
#  '₹4,85,599',
#  '₹3,10,399',
#  '₹3,99,499',
#  '₹2,61,299',
#  '₹4,79,299',
#  '₹3,27,499',
#  '₹4,06,399',
#  '₹5,18,399',
#  '₹3,02,399',
#  '₹5,30,099',
#  '₹2,58,099',
#  '₹3,17,999',
#  '₹5,63,599',
#  '₹3,46,699',
#  '₹4,93,799',
#  '₹3,48,899',
#  '₹5,16,999',
#  '₹4,48,299',
#  '₹3,43,699',
#  '₹3,75,599',
#  '₹4,14,299',
#  '₹5,62,899',
#  '₹3,07,599',
#  '₹3,07,799',
#  '₹3,94,699',
#  '₹3,44,599',
#  '₹4,54,499',
#  '₹3,76,999',
#  '₹5,62,099',
#  '₹5,68,399',
#  '₹3,80,099',
# ...

# %%
fuel_type=[]
try:
    type=driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[3]')
    for i in type:
        fuel_type.append(i.text)
except NoSuchElementException:
    fuel_type.append('-')
fuel_type
# Out:
# ['Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
# ...

# %%
owners=[]
try:
    no=driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[2]')
    for i in no:
        owners.append(i.text)
except NoSuchElementException:
    owners.append('-')
owners
# Out:
# ['1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '3rd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
# ...

# %%
kilometers=[]
try:
    kms=driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[1]')
    for i in kms:
        kilometers.append(i.text)
except NoSuchElementException:
    kilometers.append('-')
kilometers
# Out:
# ['2,876 km',
#  '3,171 km',
#  '3,600 km',
#  '16,288 km',
#  '20,241 km',
#  '10,131 km',
#  '9,924 km',
#  '4,324 km',
#  '7,284 km',
#  '13,179 km',
#  '3,243 km',
#  '2,260 km',
#  '6,145 km',
#  '9,328 km',
#  '8,236 km',
#  '15,346 km',
#  '18,020 km',
#  '7,018 km',
#  '7,431 km',
#  '24,663 km',
#  '2,484 km',
#  '21,809 km',
#  '13,079 km',
#  '16,026 km',
#  '1,278 km',
#  '6,282 km',
#  '18,371 km',
#  '18,251 km',
#  '19,070 km',
#  '34,364 km',
#  '21,025 km',
#  '14,965 km',
#  '19,815 km',
#  '26,280 km',
#  '24,198 km',
#  '11,952 km',
#  '13,741 km',
#  '16,087 km',
#  '21,601 km',
#  '20,973 km',
#  '15,116 km',
#  '27,562 km',
#  '8,929 km',
#  '14,452 km',
#  '29,906 km',
#  '11,938 km',
#  '17,703 km',
#  '15,813 km',
#  '15,028 km',
#  '17,986 km',
#  '20,711 km',
#  '15,549 km',
#  '10,937 km',
#  '25,086 km',
#  '21,239 km',
#  '28,477 km',
#  '10,336 km',
#  '15,497 km',
#  '33,463 km',
#  '7,696 km',
#  '12,620 km',
#  '32,196 km',
#  '24,687 km',
# ...

# %%
# creating a pandas dataframe
data16= pd.DataFrame({'website':'Cars24','model':model,'model_year':model,'fuel-type':fuel_type,'location':'Chennai','driven kilometers':kilometers,'No of owners':owners,'Price':Price})
  # show the dataframe
data16
# Out:
#     website                      model                 model_year fuel-type  \
# 0    Cars24           2014 Hyundai i10           2014 Hyundai i10    Petrol
# 1    Cars24       2020 Maruti S PRESSO       2020 Maruti S PRESSO    Petrol
# 2    Cars24          2014 Maruti Swift          2014 Maruti Swift    Petrol
# 3    Cars24       2013 Maruti Alto K10       2013 Maruti Alto K10    Petrol
# 4    Cars24    2011 Maruti Wagon R 1.0    2011 Maruti Wagon R 1.0    Petrol
# ..      ...                        ...                        ...       ...
# 632  Cars24  2016 Toyota Innova Crysta  2016 Toyota Innova Crysta    Diesel
# 633  Cars24         2014 Toyota Innova         2014 Toyota Innova    Diesel
# 634  Cars24         2020 Ford Ecosport         2020 Ford Ecosport    Diesel
# 635  Cars24          2017 Renault Kwid          2017 Renault Kwid    Petrol
# 636  Cars24       2017 Volkswagen Ameo       2017 Volkswagen Ameo    Petrol
#
#     location driven kilometers No of owners       Price
# ...

# %% [markdown]
# ### Kolkata

# %%
#getting the url
url = "https://www.cars24.com/buy-used-car?sort=P&storeCityId=777&pinId=700001"
driver.get(url)
time.sleep(2)

# %%
car_urls = []
url=driver.find_elements_by_xpath('//a[@class="_9Ue0B"]')       
for i in url:
    car_urls.append(i.get_attribute("href"))                       
car_urls
# Out:
# ['https://www.cars24.com/buy-used-Hyundai-Eon-2013-cars-Kolkata-1261134243/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-800-2019-cars-Kolkata-1194151540/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-800-2018-cars-Kolkata-1198761942/',
#  'https://www.cars24.com/buy-used-Hyundai-Grand-i10-2017-cars-Kolkata-1196784843/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-800-2013-cars-Kolkata-1198496847/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-2020-cars-Kolkata-1195195446/',
#  'https://www.cars24.com/buy-used-Maruti-Ertiga-2018-cars-Kolkata-1192031847/',
#  'https://www.cars24.com/buy-used-Maruti-Swift-Dzire-2016-cars-Kolkata-1194840743/',
#  'https://www.cars24.com/buy-used-Renault-Kwid-2017-cars-Kolkata-1191177749/',
#  'https://www.cars24.com/buy-used-Maruti-Alto-800-2013-cars-Kolkata-1198897844/',
#  'https://www.cars24.com/buy-used-Honda-Amaze-2014-cars-Kolkata-1199733740/',
#  'https://www.cars24.com/buy-used-Maruti-Dzire-2019-cars-Kolkata-1195414640/',
# ...

# %%
model=[]
try:
    brand=driver.find_elements_by_xpath('//h2[@class="_3FpCg"]')
    for i in brand:
        model.append(i.text)
except NoSuchElementException:
    model.append('-')
model
# Out:
# ['2013 Hyundai Eon',
#  '2019 Maruti Alto 800',
#  '2018 Maruti Alto 800',
#  '2017 Hyundai Grand i10',
#  '2013 Maruti Alto 800',
#  '2020 Maruti Alto',
#  '2018 Maruti Ertiga',
#  '2016 Maruti Swift Dzire',
#  '2017 Renault Kwid',
#  '2013 Maruti Alto 800',
#  '2014 Honda Amaze',
#  '2019 Maruti Dzire',
#  '2014 Maruti Alto 800',
#  '2015 Maruti Alto 800',
#  '2017 Maruti Alto 800',
#  '2016 Hyundai Eon',
#  '2015 Hyundai Elite i20',
#  '2014 Honda Amaze',
#  '2015 Hyundai Grand i10',
#  '2014 Maruti Swift Dzire',
#  '2017 Hyundai Verna',
#  '2015 Maruti Swift Dzire',
#  '2018 Maruti Baleno',
#  '2015 Maruti Swift Dzire',
#  '2019 Hyundai Grand i10',
#  '2015 Hyundai Elite i20',
#  '2018 Maruti Baleno',
#  '2018 Maruti Baleno',
#  '2017 Hyundai Verna',
#  '2009 Hyundai Santro Xing',
#  '2019 Maruti Dzire',
#  '2014 Hyundai Xcent',
#  '2012 Maruti Swift Dzire',
#  '2018 Hyundai Elite i20',
#  '2014 Hyundai Eon',
#  '2015 Maruti Baleno',
#  '2017 Hyundai Creta',
# ...

# %%
Price=[]
try:
    price=driver.find_elements_by_xpath('//div[@class="_7udZZ"]/span')
    for i in price:
        Price.append(i.text)
except NoSuchElementException:
    Price.append('-')
Price
# Out:
# ['₹2,03,699',
#  '₹3,19,699',
#  '₹2,82,999',
#  '₹4,08,099',
#  '₹2,25,699',
#  '₹3,83,199',
#  '₹6,74,899',
#  '₹3,95,099',
#  '₹2,67,599',
#  '₹1,91,699',
#  '₹3,06,299',
#  '₹6,23,999',
#  '₹2,02,499',
#  '₹2,21,299',
#  '₹2,69,299',
#  '₹2,63,199',
#  '₹4,17,099',
#  '₹3,09,099',
#  '₹4,12,499',
#  '₹3,68,199',
#  '₹7,83,199',
#  '₹4,05,799',
#  '₹5,61,199',
#  '₹4,32,399',
#  '₹4,93,299',
#  '₹4,05,199',
#  '₹5,65,599',
#  '₹5,85,499',
#  '₹7,24,199',
#  '₹1,46,199',
#  '₹6,03,199',
#  '₹2,82,199',
#  '₹3,23,099',
#  '₹5,04,399',
#  '₹2,00,999',
#  '₹5,20,399',
#  '₹8,50,699',
#  '₹5,02,399',
#  '₹10,45,599',
#  '₹14,20,599',
#  '₹3,98,399',
#  '₹5,19,799',
#  '₹3,39,399',
#  '₹4,36,599',
#  '₹4,71,599',
#  '₹3,25,299',
#  '₹3,38,599',
#  '₹2,51,799',
#  '₹2,10,299',
#  '₹2,23,299',
#  '₹5,08,199',
#  '₹3,59,799',
#  '₹2,98,999',
#  '₹3,95,699',
#  '₹1,88,599',
#  '₹4,91,399',
#  '₹2,87,899',
#  '₹2,48,999',
#  '₹6,17,999',
#  '₹3,14,499',
#  '₹4,52,499',
#  '₹3,78,399',
# ...

# %%
fuel_type=[]
try:
    type=driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[3]')
    for i in type:
        fuel_type.append(i.text)
except NoSuchElementException:
    fuel_type.append('-')
fuel_type
# Out:
# ['Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
# ...

# %%
owners=[]
try:
    no=driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[2]')
    for i in no:
        owners.append(i.text)
except NoSuchElementException:
    owners.append('-')
owners
# Out:
# ['1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
# ...

# %%
kilometers=[]
try:
    kms=driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[1]')
    for i in kms:
        kilometers.append(i.text)
except NoSuchElementException:
    kilometers.append('-')
kilometers
# Out:
# ['18,965 km',
#  '3,731 km',
#  '3,697 km',
#  '20,561 km',
#  '9,682 km',
#  '1,584 km',
#  '11,837 km',
#  '32,735 km',
#  '27,336 km',
#  '40,732 km',
#  '42,283 km',
#  '10,793 km',
#  '34,369 km',
#  '42,327 km',
#  '23,793 km',
#  '33,886 km',
#  '47,673 km',
#  '48,596 km',
#  '34,500 km',
#  '47,713 km',
#  '10,295 km',
#  '30,260 km',
#  '17,740 km',
#  '56,107 km',
#  '19,168 km',
#  '61,799 km',
#  '4,171 km',
#  '9,403 km',
#  '10,382 km',
#  '35,383 km',
#  '5,788 km',
#  '71,495 km',
#  '78,628 km',
#  '37,135 km',
#  '75,005 km',
#  '62,114 km',
#  '34,880 km',
#  '43,678 km',
#  '59,972 km',
#  '45,325 km',
#  '82,000 km',
#  '98,828 km',
#  '1,04,992 km',
#  '84,338 km',
#  '88,303 km',
#  '1,151 km',
#  '1,502 km',
#  '4,341 km',
#  '33,905 km',
#  '13,495 km',
#  '7,096 km',
#  '2,664 km',
#  '14,316 km',
#  '5,328 km',
#  '33,824 km',
#  '4,110 km',
#  '5,508 km',
#  '11,705 km',
#  '6,208 km',
#  '26,627 km',
#  '28,228 km',
#  '31,436 km',
#  '38,732 km',
# ...

# %%
# creating a pandas dataframe
data17= pd.DataFrame({'website':'Cars24','model':model,'fuel-type':fuel_type,'location':'Kolkata','driven kilometers':kilometers,'No of owners':owners,'Price':Price})
  # show the dataframe
data17
# Out:
#     website                   model fuel-type location driven kilometers  \
# 0    Cars24        2013 Hyundai Eon    Petrol  Kolkata         18,965 km
# 1    Cars24    2019 Maruti Alto 800    Petrol  Kolkata          3,731 km
# 2    Cars24    2018 Maruti Alto 800    Petrol  Kolkata          3,697 km
# 3    Cars24  2017 Hyundai Grand i10    Petrol  Kolkata         20,561 km
# 4    Cars24    2013 Maruti Alto 800    Petrol  Kolkata          9,682 km
# ..      ...                     ...       ...      ...               ...
# 269  Cars24     2009 Maruti Wagon R    Petrol  Kolkata         46,807 km
# 270  Cars24        2017 Maruti Ciaz    Petrol  Kolkata         41,264 km
# 271  Cars24       2017 Renault Kwid    Petrol  Kolkata         54,650 km
# 272  Cars24      2011 Toyota Innova    Diesel  Kolkata       1,52,634 km
# 273  Cars24    2014 Fiat Avvventura    Diesel  Kolkata         85,145 km
#
#     No of owners      Price
# 0      1st Owner  ₹2,03,699
# 1      1st Owner  ₹3,19,699
# ...

# %%
len(data11),len(data12),len(data13),len(data14),len(data15),len(data16),len(data17)
# Out:
# (300, 400, 580, 2175, 1607, 637, 274)

# %% [markdown]
# ### DataFrame

# %%
da=pd.concat([data11,data12,data13,data14,data15,data16,data17])
da
# Out:
#     website                      model                model_year fuel-type  \
# 0    Cars24   2011 Hyundai Santro Xing  2011 Hyundai Santro Xing    Petrol
# 1    Cars24           2009 Maruti Alto          2009 Maruti Alto    Petrol
# 2    Cars24   2011 Hyundai Santro Xing  2011 Hyundai Santro Xing    Petrol
# 3    Cars24       2015 Maruti Alto K10      2015 Maruti Alto K10    Petrol
# 4    Cars24        2016 Maruti Celerio       2016 Maruti Celerio    Petrol
# ..      ...                        ...                       ...       ...
# 344  Cars24  2017 Toyota Innova Crysta                       NaN    Diesel
# 345  Cars24             2014 Tata Zest                       NaN    Petrol
# 346  Cars24    2016 Maruti Swift Dzire                       NaN    Petrol
# 347  Cars24         2017 Ford Ecosport                       NaN    Diesel
# 348  Cars24        2013 Renault Duster                       NaN    Diesel
#
#       location driven kilometers No of owners       Price
# ...

# %% [markdown]
# ### Concatinating the dataframes

# %%
data_t=pd.concat([data,data1,data2,data3,data5,data6,data7,data8,data9,data10,data11,data12,data13,data14,data15,data16,data17],ignore_index = True)
data_t
# Out:
#                                            model model-year fuel-type  \
# 0                 Maruti Suzuki S-Cross Zeta 1.3       2016    Diesel
# 1                          Maruti Suzuki Alto LX       2007    Petrol
# 2                  Maruti Suzuki Swift Dzire ZDI       2010    Diesel
# 3                           Honda WR-V i-DTEC VX       2017    Diesel
# 4      Ford Ecosport 1.5 Petrol Titanium Plus AT       2017    Petrol
# ...                                          ...        ...       ...
# 10460                        2009 Maruti Wagon R        NaN    Petrol
# 10461                           2017 Maruti Ciaz        NaN    Petrol
# 10462                          2017 Renault Kwid        NaN    Petrol
# 10463                         2011 Toyota Innova        NaN    Diesel
# 10464                       2014 Fiat Avvventura        NaN    Diesel
#
#          location website driven kilometers No of owners       Price  \
# ...

# %%
for column in data_t.columns:
    data_t[column]=data_t[column].str.replace(r'\W','')
data_t
# Out:
#                                     model model-year fuel-type   location  \
# 0                MarutiSuzukiSCrossZeta13       2016    Diesel  PANCHKULA
# 1                      MarutiSuzukiAltoLX       2007    Petrol  BENGALURU
# 2               MarutiSuzukiSwiftDzireZDI       2010    Diesel  AHMEDABAD
# 3                         HondaWRViDTECVX       2017    Diesel      DELHI
# 4      FordEcosport15PetrolTitaniumPlusAT       2017    Petrol      DELHI
# ...                                   ...        ...       ...        ...
# 10460                    2009MarutiWagonR        NaN    Petrol    Kolkata
# 10461                      2017MarutiCiaz        NaN    Petrol    Kolkata
# 10462                     2017RenaultKwid        NaN    Petrol    Kolkata
# 10463                    2011ToyotaInnova        NaN    Diesel    Kolkata
# 10464                  2014FiatAvvventura        NaN    Diesel    Kolkata
#
#       website driven kilometers No of owners   Price model_year
# ...

# %% [markdown]
# ### Saving to excel file

# %%
  # writing to Excel
datatoexcel = pd.ExcelWriter('cars_data.xlsx')
  
# write DataFrame to excel
data_t.to_excel(datatoexcel)
  
# save to excel
datatoexcel.save()
